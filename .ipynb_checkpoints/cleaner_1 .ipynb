# %%
import sys
import re

f= open(r'stopwords_en.txt')
fh = f.read()
stop_words = []
for word in fh:
  stop_words.append(word)
print(len(stop_words))
# Out:
# 3586

# %%
def count_paragraph_tags_on_same_level_with_depth(element, depth=0):
    paragraph_tags = element.find_all('p', recursive=False)
    if paragraph_tags:
        return len(paragraph_tags), depth
    for child in element.children:
        try:
            num_paragraphs, child_depth = count_paragraph_tags_on_same_level_with_depth(child, depth=depth+1)
        except:
            continue
        if num_paragraphs:
            return num_paragraphs, child_depth
    return 0, 0

# %%
def get_text(node):
    try:
                    text_node = parser.get_text_by_tag(tag_name=node['tag'], attribute_name='class', attribute_value=node['attributes']['class'])
    except:
                    text_node = parser.get_text_by_tag(tag_name=node['tag'])
    #             print(text_node)
    result_string = ''.join(text_node)
    clean_string = re.sub(r'[\n\t]', '', result_string)
#     print(clean_string)
    return clean_string

def get_text_reg(node):
    try:
                    text_node = parser.get_text_by_tag(tag_name=node['tag'], attribute_name='class', attribute_value=node['attributes']['class'])
    except:
                    text_node = parser.get_text_by_tag(tag_name=node['tag'])
    #             print(text_node)
    result_string = ''.join(text_node)
    return result_string

# %%
from bs4 import BeautifulSoup
from dateutil.parser import parse as date_parser


class CustomExtractor:
    def __init__(self):
        self.stopwords = stop_words

    def calculate_gravity_score(self, tag):
        # Your custom logic to calculate the gravity score
        # This example uses the length of text content as a score
        text_content = tag.get_text(strip=True)
        return len(text_content)

    def previousSiblings(self,node):
      try:
        return [n for n in node.itersiblings(preceding=True)]
      except:
        return []
    def walk_siblings(self, node):
        # Iterate over siblings
        return self.previousSiblings(node)

    def is_highlink_density(self, node):

        # For simplicity, this example checks if the node contains more than 5 links
        links = node.find_all('a')
        return len(links) > 25



    def is_boostable(self, node):
        para = "p"
        steps_away = 0
        minimum_stopword_count = 2
        max_stepsaway_from_node = 3

        nodes = self.walk_siblings(node)
        # print(len(nodes))
        for current_node in nodes:
            current_node_tag = current_node.name
            if current_node_tag == para:
                if steps_away >= max_stepsaway_from_node:
                    return False
                paragraph_text = current_node.get_text(strip=True)
                word_stats = self.get_stopword_count(paragraph_text)
                # print(word_stats)
                if word_stats > minimum_stopword_count:
                    return True
                steps_away += 1
        return False

    def get_stopword_count(self, text):
        text = re.sub(r'[^\w\s]', '', text)
        words = [word.lower() for word in text.split()]

        sm = 0
        for word in words:
          if(word in self.stopwords):
            sm+=1
        return sm


    def count_paragraph_tags_on_same_level_with_depth(element, depth=0):
        paragraph_tags = element.find_all('p', recursive=False)
        if paragraph_tags:
            return len(paragraph_tags), depth
        for child in element.children:
            if node is not None:
                num_paragraphs, child_depth = count_paragraph_tags_on_same_level_with_depth(child, depth=depth+1)
                if num_paragraphs:
                    return num_paragraphs, child_depth
            else:
                return 0, 0
        return 0, 0



    def calculate_best_node(self, soup):
        top_node = None
        top_node_score = 0
        nodes_to_check = self.nodes_to_check(soup)
        # print(nodes_to_check)
        starting_boost = 1.0
        cnt = 0
        i = 0
        parent_nodes = []
        nodes_with_text = []


        for node in nodes_to_check:
            text_node = node.get_text()
            word_stats = self.get_stopword_count(text_node)
#             print(node.get_text(strip=True))
            # print(word_stats)
            high_link_density = self.is_highlink_density(node)
            if word_stats >= 2 and not high_link_density:
                nodes_with_text.append(node)

        nodes_number = len(nodes_with_text)
        negative_scoring = 0
        bottom_negativescore_nodes = nodes_number * 0.25

#         print(nodes_with_text)
        for node in nodes_with_text:

#             print(type(node))
            boost_score = 0
            depth = 0

            try:
                boost_score, depth = count_paragraph_tags_on_same_level_with_depth(node)
    #                print(node['class'], " ", boost_score)
            except:
                boost_score = 0


            text_node = node.get_text(strip=True)
            word_stats = self.get_stopword_count(text_node)/2
            temp = 0

            try:
                temp = len(node.content)
            except:
                pass

            boost_score2 = 0
            if(self.is_boostable(node)):
              print("Hello ")
              boost_score2 = 5
            boost_score = boost_score*(0.95**(depth+1))
            upscore = word_stats + boost_score + boost_score2

#             print(upscore," ",word_stats," ",boost_score," ",word_stats+boost_score)

#             if(node.has_attr('class')):
#                 print(node['class'])


            parent_node = node.parent
            self.update_score(node,upscore)




#             print(node.name," ",word_stats," ",boost_score," ",node['score']," ",upscore)

            x = node
            if(node.name == 'p'):
                for i in range(5):
                    x = x.parent
                    self.update_score(x,upscore*((0.8)**i))

            if parent_node not in parent_nodes:
                parent_nodes.append(parent_node)

            parent_parent_node = parent_node.parent
            if parent_parent_node is not None:
                self.update_node_count(parent_parent_node, 1)

                if parent_parent_node not in parent_nodes:
                    parent_nodes.append(parent_parent_node)
            cnt += 1
            i += 1

        parent_nodes.append(node)

        for e in parent_nodes:
            score = self.get_score(e)

            if score > top_node_score:
#                 print(node.name," ",node['score'])
                top_node = e
                top_node_score = score

            if top_node is None:
                top_node = e

        return top_node

    def nodes_to_check(self, soup):
        nodes_to_check = []
        for tag in ['div','p', 'pre', 'td']:
            items = soup.find_all(tag)
            nodes_to_check += items
#         print(nodes_to_check)
        return nodes_to_check


    def update_score(self, node, score):
        if 'score' not in node:
            node['score'] = len(node.get_text(strip=True))**(0.5)
        node['score'] += score

    def update_node_count(self, node, count):
        if 'count' not in node:
            node['count'] = 0

        node['count'] += count

    def get_score(self, node):
        return node.get('score', 0)

    def get_authors(self, doc):
        def contains_digits(d):
            for char in d:
                if char.isdigit():
                    return True
            return False

        def unique_list(lst):
            count = {}
            list = []
            for item in lst:
                if item.lower() in count:
                    continue
                count[item.lower()] = 1
                list.append(item.title())
            return list

        def parse(str):

            str = ''.join(char for char in str if char != '<' and char != '>')

            str = str.replace('By:', '').replace('From:', '').strip()

            names = [s.strip() for s in re.split(r"[^\w\'\-\.]", str) if s]


            authors = []
            current = []
            delimiters = ['and', ',', '']

            for name in names:
                if name in delimiters:
                    if len(current) > 0:
                        authors.append(' '.join(current))
                        current = []
                elif not contains_digits(name):
                    current.append(name)

            valid_name = (len(current) >= 2)
            if valid_name:
                authors.append(' '.join(current))

            return authors
        patterns=[re.compile(r'(?:author.*?name|name.*?author)', re.IGNORECASE)]
        attributes = ['name', 'rel', 'itemprop', 'class', 'id']
        variables = ['author', 'byline', 'dc.creator', 'byl','group-info']
        matches = []
        authors = []

        for attr in attributes:
            for val in variables+patterns:
                found = doc.find_all(attrs={attr: val})
                matches.extend(found)


        for match in matches:
            content = ''
            if match.tag == 'meta':
                content_value = match.get('content')
                if len(content_value) > 0:
                    content = content_value[0]
            else:
                content = match.get_text() or ''
            if len(content) > 0:
                authors.extend(parse(content))

        return unique_list(authors)

    def publishing_date(self, url, doc):
        def parse_date(str):
            if str:
                try:
                    return date_parser(str)
                except (ValueError, OverflowError, AttributeError, TypeError):
                    return None


        STRICT_DATE_REGEX = re.compile(r'\/(\d{4})\/(\d{2})\/(\d{2})\/')
        date_pattern = re.compile(r'(\d{2} [a-zA-Z]{3} \d{4}) (\d{2}:\d{2}[APMapm]{2})')
        date_match = STRICT_DATE_REGEX.search(url)
        if date_match:
            str = date_match.group(0)
            datetime = parse_date(str)
            if datetime:
                return datetime


        date_tags = [
            {'attribute': ('property', 'rnews:datePublished'), 'content': 'content'},
            {'attribute': ('property', 'article:published_time'), 'content': 'content'},
            {'attribute': ('name', 'OriginalPublicationDate'), 'content': 'content'},
            {'attribute': ('itemprop', 'datePublished'), 'content': 'datetime'},
            {'attribute': ('property', 'og:published_time'), 'content': 'content'},
            {'attribute': ('name', 'article_date_original'), 'content': 'content'},
            {'attribute': ('name', 'publication_date'), 'content': 'content'},
            {'attribute': ('name', 'sailthru.date'), 'content': 'content'},
            {'attribute': ('name', 'PublishDate'), 'content': 'content'},
            {'attribute': ('pubdate', 'pubdate'), 'content': 'datetime'},
            {'attribute': ('name', 'publish_date'), 'content': 'content'},
        ]



        patterns = re.compile(r'(?:article.*publish|publish.*article|\bdate\b|\btime\b)')

        for tags in date_tags:
            meta_tags = doc.find_all(attrs={tags['attribute'][0]: tags['attribute'][1]})
            if meta_tags:
                str = meta_tags[0].get(tags['content'])
                datetime = parse_date(str)
                if datetime:
                    return datetime

        additional_date_tag = doc.find('div', class_=lambda c: c and patterns.search(c))
        if additional_date_tag:
            str = additional_date_tag.get_text(strip=True)
            match = date_pattern.search(str)
            if match:
                date_str, time_str = match.groups()

                # Combine date and time, then parse using dateutil.parser
                datetime_str = f"{date_str} {time_str}"
                datetime_obj = date_parser(datetime_str)
            return datetime_obj



        # If none of the strategies work, return None
        return None
    def split_title(self,title, splitter, hint=None):
        """Split the title to best part possible"""
        large_text_length = 0
        large_text_index = 0
        title_pieces = title.split(splitter)
        if hint and hint!='':
            filter_regex = re.compile(r'[^a-zA-Z0-9\ ]')
            hint = filter_regex.sub('', hint).lower()

        # find the largest title piece
        for i, title_piece in enumerate(title_pieces):
            current = title_piece.strip()
            #Immediately break if any part matches
            if hint and hint in filter_regex.sub('', current).lower():
                large_text_index = i
                break
            if len(current) > large_text_length:
                large_text_length = len(current)
                large_text_index = i

    #     Even if no part matches with hint(h1) if prints simply the longest part as the parts
    #     are usually of independent meaning
        title = title_pieces[large_text_index]
        return title
    def get_title(self,soup):
        """Explicit rules:
        1. title == h1, no need to split
        2. h1 similar to og:title, use h1
        3. title contains h1, title contains og:title, len(h1) > len(og:title), use h1
        4. title starts with og:title, use og:title
        5. use title, after splitting
        """
        title = ''
        title_element = soup.title

        # no title found
        if title_element is None or len(title_element) == 0:
            print("Error")
            return title

        # title elem found
        title_text = title_element.text
        used_delimeter = False

    #     title from h1
            # - extract the longest text from all h1 elements
        # - too short texts (fewer than 2 words) are discarded
        # - clean double spaces
    #     h1_element = soup.find_all('h1')[0]
    #     title_text_h1 = h1_element.text
        title_text_h1=''
        title_element_h1_list = soup.find_all('h1')
        title_text_h1_list = [tag.get_text(strip=True) for tag in title_element_h1_list]
        if title_text_h1_list:
            title_text_h1_list.sort(key=len, reverse=True)
            #longest title
            title_text_h1 = title_text_h1_list[0]
            # clean double spaces
            title_text_h1 = ' '.join([x for x in title_text_h1.split() if x])
        #title from meta tag(not user-visible)
        meta_tag_content = soup.find({'meta': {'property': 'og:title'}})
        if not meta_tag_content:
            meta_tag_content = soup.find({'meta': {'name': 'og:title'}})
        title_text_meta = meta_tag_content.get('content', '')  # Empty string if no meta tag found
        # Further filtering of unwanted characters
        # Alphanumeric characters, punctuation and alphanumeric
        filter_regex = re.compile(r'[^a-zA-Z0-9\ ]')
        filter_title_text = filter_regex.sub('', title_text).lower()
        filter_title_text_h1 = filter_regex.sub('', title_text_h1).lower()
        filter_title_text_meta = filter_regex.sub('', title_text_meta).lower()

        # Case1: If both matches don't do anything
        if title_text_h1 == title_text:
            used_delimeter = True
        # Case2: h1 and meta tag matches(either of h1 or meta)
        elif filter_title_text_h1 and filter_title_text_h1 == filter_title_text_meta:
            title_text = title_text_h1
            used_delimeter = True
        # Case3: If both h1 and meta are a substring of title_text(use h1)
        elif filter_title_text_h1 and filter_title_text_h1 in filter_title_text and filter_title_text_meta in filter_title_text  and len(title_text_h1) > len(title_text_meta):
            title_text = title_text_h1
            used_delimeter = True
        # Case4: If title_text startswith meta text(replace with meta)
        elif filter_title_text_meta and filter_title_text_meta != filter_title_text and filter_title_text.startswith(filter_title_text_meta):
            title_text = title_text_meta
            used_delimeter = True

        # If none of the above condition is matched, means a delimiter must be present between them
        # Now individually parts separated by delimiter has to be checked and now we check with h1 tag only(no meta tag)-Observation based
        if not used_delimeter and '|' in title_text:
            title_text = self.split_title(title_text, '|', title_text_h1)
            used_delimeter = True

        # self.split title with -
        if not used_delimeter and '-' in title_text:
            title_text = self.split_title(title_text, '-', title_text_h1)
            used_delimeter = True

        # self.split title with _
        if not used_delimeter and '_' in title_text:
            title_text = self.split_title(title_text, '_', title_text_h1)
            used_delimeter = True

        # self.split title with /
        if not used_delimeter and '/' in title_text:
            title_text = self.split_title(title_text, '/', title_text_h1)
            used_delimeter = True

        # self.split title with »
        if not used_delimeter and ' » ' in title_text:
            title_text = self.split_title(title_text, ' » ', title_text_h1)
            used_delimeter = True
        return title_text

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from urllib.parse import urlencode

url = "https://edition.cnn.com/2024/02/25/politics/man-sets-himself-on-fire-israeli-embassy-washington-dc/index.html"

proxies = {
"http": "http://scraperapi:8355bf750256f87924cb321115d06996@proxy-server.scraperapi.com:8001"
}
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}

response = requests.get(url,headers=headers,proxies=proxies,verify=False)
API_KEY = "8355bf750256f87924cb321115d06996"
params = {'api_key': API_KEY, 'url': url}
response = requests.get('http://api.scraperapi.com/', params=urlencode(params))
response.raise_for_status()

soup = BeautifulSoup(response.text, 'html.parser')

# print(soup)
# Create an instance of CustomExtractor
extractor = CustomExtractor()


authors_list=extractor.get_authors(soup);
print("authors  are")

if authors_list:

    for author in authors_list:
        print(author)

else:
    print("No authors found.")
date=extractor.publishing_date(url,soup)

print("date of publication:",date)

title_list=extractor.get_title(soup);
print("title  is/are")

print(extractor.get_title(soup))


# Calculate best node based on custom gravity scores
best_node = extractor.calculate_best_node(soup)

print("\n\n")
# Now, you can access the best node and its gravity score

if best_node:
    print(f"Best Node: {best_node['class']}, Gravity Score: {best_node.get('score', 0)}")
    print(best_node.get_text(strip=True))
else:
    print("No best node found.")
# Out:
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py:1020: InsecureRequestWarning: Unverified HTTPS request is being made to host 'edition.cnn.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# authors  are
# By Casey Gannon Jennifer Hansler
# Rashard Rose Cnn
# date of publication: 2024-02-25 00:00:00
# title  is/are
# US airman dies after setting himself on fire outside Israeli Embassy in Washington
#
#
#
# Best Node: ['article__main'], Gravity Score: 71.01044834303673
# Video Ad FeedbackUS airman dies after self-immolation in protest in front of Israeli embassy03:02- Source:CNNPolitics of the Day18 videosVideo Ad FeedbackUS airman dies after self-immolation in protest in front of Israeli embassy03:02Now playing- Source:CNNVideo Ad FeedbackWatch Biden's revealing hot mic moments from State of the Union03:21Now playing- Source:CNNVideo Ad Feedback'His Achilles heel': Reporter discusses whether Trump can pay $454M legal penalty02:09Now playing- Source:CNNVideo Ad FeedbackHear Republicans' reaction to Santos announcing he's running for Congress again02:32Now playing- Source:CNNVideo Ad Feedback'Don't repeat this': Biden's remark about Netanyahu caught on hot mic01:06Now playing- Source:CNNVideo Ad FeedbackTrump mocks Biden during the president's address01:45Now playing- Source:CNNVideo Ad FeedbackRepublican strategist: Biden 'was on his game' during State of the Union speech01:16Now playing- Source:CNNVideo Ad FeedbackGOP senator says 'that's true' in agreement with Biden while Republicans booed00:52Now playing- Source:CNNVideo Ad FeedbackAlyssa Farah Griffin reacts to the staging of the GOP response01:05Now playing- Source:CNNVideo Ad Feedback'Not a big thing': Pelosi defends Biden's use of the word 'illegal' to describe migrant01:12Now playing- Source:CNNVideo Ad FeedbackHear Biden's message to the Israeli government about humanitarian aid in Gaza02:36Now playing- Source:CNNVideo Ad FeedbackLawmakers say bill that could ban TikTok wouldn't violate free speech. Hear why03:32Now playing- Source:CNNVideo Ad FeedbackWhy Biden's guest list is key for his State of the Union speech01:11Now playing- Source:CNNVideo Ad FeedbackSee Biden's reaction to fictional presidents' advice00:54Now playing- Source:CNNVideo Ad FeedbackAxelrod says this is what Biden needs to do during his State of the Union speech to appeal to voters01:24Now playing- Source:CNNVideo Ad FeedbackHaberman: This is what worries Trump's camp today02:16Now playing- Source:CNNVideo Ad FeedbackCharles Barkley responds to criticism about Trump mug shot comments03:13Now playing- Source:CNNVideo Ad Feedback'Really crushing': Woman denied abortion in Texas describes legal hurdles01:32Now playing- Source:CNNSee More VideosCNN—An active-duty member of the US Air Force who set himself on fire outside the Israeli Embassy in Washington, DC, on Sunday, has died, authorities said.Aaron Bushnell, 25, said in a video of the incident obtained by CNN that he would “no longer be complicit in genocide” and that his suffering was minimal compared to that of Palestinians as the humanitarian crisis persists in Gaza.He then sets the recording device on the ground before pouring an unknown liquid over himself and igniting it while yelling “Free Palestine” repeatedly. He eventually collapses as police officers rush to douse the flames with fire extinguishers.He was subsequently transported by DC Fire and emergency services to a local hospital where he died, the Metropolitan Police Department said in a statement. Local police are working with the US Secret Service and the Bureau of Alcohol, Tobacco, Firearms and Explosives to investigate the incident, which took place around 1 p.m. in northwest Washington.Bushnell’s identity was confirmed by MPD on Sunday. The Air Force also confirmed his identity Monday and said he was a cyber defense operations specialist assigned to the 70th Intelligence, Surveillance and Reconnaissance (ISR) Wing. He served with the 531st Intelligence Support Squadron and had been on active duty since May 2020, according to the Air Force.“We extend our deepest sympathies to the family and friends of Senior Airman Bushnell. Our thoughts and prayers are with them, and we ask that you respect their privacy during this difficult time,” said Col. Celina Noyes, the commander of the 70th ISR Wing, in a statement.The 70th ISR Wing gathers intelligence across air, space and cyberspace, according to its website, working alongside the National Security A ...

# %%
pip install import-ipynb
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: import-ipynb in /home/joyjeet031/.local/lib/python3.10/site-packages (0.1.4)
# Requirement already satisfied: IPython in /usr/lib/python3/dist-packages (from import-ipynb) (7.31.1)
# Requirement already satisfied: nbformat in /usr/lib/python3/dist-packages (from import-ipynb) (5.1.3)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import import_ipynb
from lxmlparser1 import HTMLParser
# Out:
# importing Jupyter notebook from lxmlparser1.ipynb

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from urllib.parse import urlencode

url = "https://timesofindia.indiatimes.com/sports/cricket/england-in-india/virat-kohli-withdraws-from-first-two-england-tests-bcci/articleshow/107051526.cms"

proxies = {
"http": "http://scraperapi:8355bf750256f87924cb321115d06996@proxy-server.scraperapi.com:8001"
}
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}

response = requests.get(url,headers=headers,proxies=proxies,verify=False)
API_KEY = "8355bf750256f87924cb321115d06996"
params = {'api_key': API_KEY, 'url': url}
response = requests.get('http://api.scraperapi.com/', params=urlencode(params))
response.raise_for_status()
# Out:
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py:1020: InsecureRequestWarning: Unverified HTTPS request is being made to host 'timesofindia.indiatimes.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
parser = HTMLParser(response.text)

# %%
tags = parser.findalltags('div')

# %%
tags
# Out:
# [{'tag': 'div', 'attributes': {'class': 'appgutter'}},
#  {'tag': 'div', 'attributes': {'id': 'TOI_appgutter_left'}},
#  {'tag': 'div', 'attributes': {'id': 'TOI_appgutter_right'}},
#  {'tag': 'div', 'attributes': {'id': 'app'}},
#  {'tag': 'div',
#   'attributes': {'class': 'nonAppView layout_type_2', 'data-reactroot': ''}},
#  {'tag': 'div', 'attributes': {'class': 'topBand_adwrapper'}},
#  {'tag': 'div',
#   'attributes': {'id': 'div-gpt-ad-topband-1628142867492-0-1', 'class': ''}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div', 'attributes': {'class': 'mPws3 d_jsH'}},
#  {'tag': 'div',
#   'attributes': {'id': 'div-gpt-ad-1416990040345-14937aae-7a5b-4e32-9c01-28b481655225-atf-1',
#    'class': 'desktop_paisa OaOmW snowwhite'}},
#  {'tag': 'div', 'attributes': {'class': 'header-container contentwrapper'}},
#  {'tag': 'div',
#   'attributes': {'id': 'top-bar-container',
#    'class': 'R5YFj L1k6M top-area as_topBar'}},
#  {'tag': 'div', 'attributes': {'class': 'contentwrapper'}},
#  {'tag': 'div', 'attributes': {'class': 'MvyrO  rel'}},
#  {'tag': 'div', 'attributes': {'class': 'awuxh lXs66'}},
#  {'tag': 'div', 'attributes': {'class': 'HTz_b'}},
#  {'tag': 'div', 'attributes': {'class': '\n         FNwgv\n         FhCmn'}},
#  {'tag': 'div', 'attributes': {'class': 'z89UZ Xzsy6'}},
#  {'tag': 'div', 'attributes': {'class': 'HTz_b'}},
#  {'tag': 'div', 'attributes': {'class': 'sDvqk'}},
#  {'tag': 'div', 'attributes': {'class': 'awuxh lXs66'}},
#  {'tag': 'div', 'attributes': {'class': 'NC4Wd'}},
#  {'tag': 'div',
#   'attributes': {'class': 'login_fix user_area clearfix  hide '}},
#  {'tag': 'div', 'attributes': {'class': ''}},
#  {'tag': 'div', 'attributes': {'id': 'login-popup', 'class': ''}},
#  {'tag': 'div', 'attributes': {'class': 'Mivr2 ZwGeW '}},
#  {'tag': 'div', 'attributes': {'class': 'YZQav navigation'}},
#  {'tag': 'div',
#   'attributes': {'class': 'w4nQT\n              \n                undefined'}},
#  {'tag': 'div', 'attributes': {'class': 'contentwrapper rpos'}},
#  {'tag': 'div',
#   'attributes': {'itemtype': 'https://schema.org/Organization',
#    'itemscope': '',
#    'itemprop': 'publisher',
#    'class': 'xfVsJ L1plO'}},
#  {'tag': 'div', 'attributes': {'class': 'EV3DB Kikxk '}},
#  {'tag': 'div', 'attributes': {'class': 'K8FEs'}},
#  {'tag': 'div', 'attributes': {'class': ' Ec__7 AuiwR undefined'}},
#  {'tag': 'div', 'attributes': {'class': 'contentwrapper small rel'}},
#  {'tag': 'div', 'attributes': {'class': 'Ehwb3 gCqY3'}},
#  {'tag': 'div', 'attributes': {'class': 'zt6aW'}},
#  {'tag': 'div', 'attributes': {'class': 'hamburg bfa1o'}},
#  {'tag': 'div', 'attributes': {'class': 'contentwrapper clearfix    '}},
#  {'tag': 'div', 'attributes': {'id': 'desktop_minitv_view'}},
#  {'tag': 'div', 'attributes': {'data-resizer-target': 'cw'}},
#  {'tag': 'div', 'attributes': {'class': 'rbqRL  hide '}},
#  {'tag': 'div', 'attributes': {'class': 'yXDMI contentwrapper clearfix'}},
#  {'tag': 'div', 'attributes': {'class': 'hSQoA '}},
#  {'tag': 'div', 'attributes': {'class': 'ZNrXe share'}},
#  {'tag': 'div', 'attributes': {'class': '_87noh qpCIF  Wz_06  undefined'}},
#  {'tag': 'div', 'attributes': {'class': 'KZuc8 ', 'style': 'width:0%'}},
#  {'tag': 'div',
#   'attributes': {'id': 'toi-article-container-107051526',
#    'class': 'clearfix rel',
#    'data-scrollga': 'WEB-articleshowv2#scroll#scroll_starts'}},
#  {'tag': 'div',
#   'attributes': {'data-type': 'in_view', 'class': 'loadable-inview  '}},
#  {'tag': 'div',
#   'attributes': {'class': 'NvaTO  ',
#    'data-translate-id': 'cw',
#    'data-translate-page': '1',
#    'data-font': 'medium',
#    'data-mspsectionname': 'England in India',
#    'data-articlemsid': '107051526'}},
#  {'tag': 'div', 'attributes': {'class': 'cCU6C innerbody '}},
#  {'tag': 'div', 'attributes': {'class': 'okf2Z '}},
#  {'tag': 'div', 'attributes': {'class': 'C4nji'}},
#  {'tag': 'div', 'attributes': {'class': 'undefined xciRh'}},
#  {'tag': 'div', 'attributes': {'class': 'rwKrk'}},
#  {'tag': 'div', 'attributes': {'class': 'trending_sliderContent'}},
#  {'tag': 'div',
#   'attributes': {'class': 'slick-slider slider variable-width slick-initialized',
#    'dir': 'ltr'}},
#  {'tag': 'div', 'attributes': {'class': 'slick-list'}},
#  {'tag': 'div',
#   'attributes': {'class': 'slick-track',
#    'style': 'width:0128 px139 px112 px112 px110 px113 px116 px114 px123 px111 px111 px123 px114 px116 px113 px110 px112 px112 px139 px128 px128 px139 px112 px112 px110 px113 px116 px114 px123 px111 pxpx;left:NaNpx'}},
#  {'tag': 'div',
#   'attributes': {'style': 'width:128 px',
#    'data-index': '-10',
#    'tabindex': '-1',
#    'class': 'slick-slide slick-cloned',
#    'aria-hidden': 'true'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'class': 'c5HdF',
#    'style': 'width:100%;display:inline-block',
#    'tabindex': '-1'}},
#  {'tag': 'div',
#   'attributes': {'style': 'width:139 px',
#    'data-index': '-9',
#    'tabindex': '-1',
#    'class': 'slick-slide slick-cloned',
#    'aria-hidden': 'true'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'class': 'c5HdF',
#    'style': 'width:100%;display:inline-block',
#    'tabindex': '-1'}},
#  {'tag': 'div',
#   'attributes': {'style': 'width:112 px',
#    'data-index': '-8',
#    'tabindex': '-1',
#    'class': 'slick-slide slick-cloned',
#    'aria-hidden': 'true'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'class': 'c5HdF',
#    'style': 'width:100%;display:inline-block',
#    'tabindex': '-1'}},
#  {'tag': 'div',
#   'attributes': {'style': 'width:112 px',
#    'data-index': '-7',
#    'tabindex': '-1',
#    'class': 'slick-slide slick-cloned',
#    'aria-hidden': 'true'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'class': 'c5HdF',
#    'style': 'width:100%;display:inline-block',
#    'tabindex': '-1'}},
#  {'tag': 'div',
#   'attributes': {'style': 'width:110 px',
#    'data-index': '-6',
#    'tabindex': '-1',
#    'class': 'slick-slide slick-cloned',
#    'aria-hidden': 'true'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'class': 'c5HdF',
#    'style': 'width:100%;display:inline-block',
#    'tabindex': '-1'}},
#  {'tag': 'div',
#   'attributes': {'style': 'width:113 px',
#    'data-index': '-5',
#    'tabindex': '-1',
#    'class': 'slick-slide slick-cloned',
#    'aria-hidden': 'true'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'class': 'c5HdF',
#    'style': 'width:100%;display:inline-block',
#    'tabindex': '-1'}},
#  {'tag': 'div',
#   'attributes': {'style': 'width:116 px',
#    'data-index': '-4',
#    'tabindex': '-1',
#    'class': 'slick-slide slick-cloned',
#    'aria-hidden': 'true'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'class': 'c5HdF',
#    'style': 'width:100%;display:inline-block',
#    'tabindex': '-1'}},
#  {'tag': 'div',
#   'attributes': {'style': 'width:114 px',
#    'data-index': '-3',
#    'tabindex': '-1',
#    'class': 'slick-slide slick-cloned',
#    'aria-hidden': 'true'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'class': 'c5HdF',
#    'style': 'width:100%;display:inline-block',
#    'tabindex': '-1'}},
#  {'tag': 'div',
#   'attributes': {'style': 'width:123 px',
#    'data-index': '-2',
#    'tabindex': '-1',
#    'class': 'slick-slide slick-cloned',
#    'aria-hidden': 'true'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'class': 'c5HdF',
#    'style': 'width:100%;display:inline-block',
#    'tabindex': '-1'}},
#  {'tag': 'div',
#   'attributes': {'style': 'width:111 px',
#    'data-index': '-1',
#    'tabindex': '-1',
#    'class': 'slick-slide slick-cloned',
#    'aria-hidden': 'true'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'class': 'c5HdF',
#    'style': 'width:100%;display:inline-block',
#    'tabindex': '-1'}},
#  {'tag': 'div',
#   'attributes': {'style': 'outline:none;width:128 px',
#    'data-index': '0',
#    'class': 'slick-slide slick-active slick-current',
#    'tabindex': '-1',
#    'aria-hidden': 'false'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'class': 'c5HdF',
#    'style': 'width:100%;display:inline-block',
#    'tabindex': '-1'}},
#  {'tag': 'div',
#   'attributes': {'style': 'outline:none;width:139 px',
#    'data-index': '1',
#    'class': 'slick-slide slick-active',
#    'tabindex': '-1',
#    'aria-hidden': 'false'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'class': 'c5HdF',
#    'style': 'width:100%;display:inline-block',
#    'tabindex': '-1'}},
#  {'tag': 'div',
#   'attributes': {'style': 'outline:none;width:112 px',
#    'data-index': '2',
#    'class': 'slick-slide slick-active',
#    'tabindex': '-1',
#    'aria-hidden': 'false'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'class': 'c5HdF',
#    'style': 'width:100%;display:inline-block',
#    'tabindex': '-1'}},
#  {'tag': 'div',
#   'attributes': {'style': 'outline:none;width:112 px',
#    'data-index': '3',
#    'class': 'slick-slide slick-active',
#    'tabindex': '-1',
#    'aria-hidden': 'false'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'class': 'c5HdF',
#    'style': 'width:100%;display:inline-block',
#    'tabindex': '-1'}},
#  {'tag': 'div',
#   'attributes': {'style': 'outline:none;width:110 px',
#    'data-index': '4',
#    'class': 'slick-slide',
#    'tabindex': '-1',
#    'aria-hidden': 'true'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'class': 'c5HdF',
#    'style': 'width:100%;display:inline-block',
#    'tabindex': '-1'}},
#  {'tag': 'div',
#   'attributes': {'style': 'outline:none;width:113 px',
#    'data-index': '5',
#    'class': 'slick-slide',
#    'tabindex': '-1',
#    'aria-hidden': 'true'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'class': 'c5HdF',
#    'style': 'width:100%;display:inline-block',
#    'tabindex': '-1'}},
#  {'tag': 'div',
#   'attributes': {'style': 'outline:none;width:116 px',
#    'data-index': '6',
#    'class': 'slick-slide',
#    'tabindex': '-1',
#    'aria-hidden': 'true'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'class': 'c5HdF',
#    'style': 'width:100%;display:inline-block',
#    'tabindex': '-1'}},
#  {'tag': 'div',
#   'attributes': {'style': 'outline:none;width:114 px',
#    'data-index': '7',
#    'class': 'slick-slide',
#    'tabindex': '-1',
#    'aria-hidden': 'true'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'class': 'c5HdF',
#    'style': 'width:100%;display:inline-block',
#    'tabindex': '-1'}},
#  {'tag': 'div',
#   'attributes': {'style': 'outline:none;width:123 px',
#    'data-index': '8',
#    'class': 'slick-slide',
#    'tabindex': '-1',
#    'aria-hidden': 'true'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'class': 'c5HdF',
#    'style': 'width:100%;display:inline-block',
#    'tabindex': '-1'}},
#  {'tag': 'div',
#   'attributes': {'style': 'outline:none;width:111 px',
#    'data-index': '9',
#    'class': 'slick-slide',
#    'tabindex': '-1',
#    'aria-hidden': 'true'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'class': 'c5HdF',
#    'style': 'width:100%;display:inline-block',
#    'tabindex': '-1'}},
#  {'tag': 'div',
#   'attributes': {'style': 'width:128 px',
#    'data-index': '10',
#    'tabindex': '-1',
#    'class': 'slick-slide slick-cloned',
#    'aria-hidden': 'true'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'class': 'c5HdF',
#    'style': 'width:100%;display:inline-block',
#    'tabindex': '-1'}},
#  {'tag': 'div',
#   'attributes': {'style': 'width:139 px',
#    'data-index': '11',
#    'tabindex': '-1',
#    'class': 'slick-slide slick-cloned',
#    'aria-hidden': 'true'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'class': 'c5HdF',
#    'style': 'width:100%;display:inline-block',
#    'tabindex': '-1'}},
#  {'tag': 'div',
#   'attributes': {'style': 'width:112 px',
#    'data-index': '12',
#    'tabindex': '-1',
#    'class': 'slick-slide slick-cloned',
#    'aria-hidden': 'true'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'class': 'c5HdF',
#    'style': 'width:100%;display:inline-block',
#    'tabindex': '-1'}},
#  {'tag': 'div',
#   'attributes': {'style': 'width:112 px',
#    'data-index': '13',
#    'tabindex': '-1',
#    'class': 'slick-slide slick-cloned',
#    'aria-hidden': 'true'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'class': 'c5HdF',
#    'style': 'width:100%;display:inline-block',
#    'tabindex': '-1'}},
#  {'tag': 'div',
#   'attributes': {'style': 'width:110 px',
#    'data-index': '14',
#    'tabindex': '-1',
#    'class': 'slick-slide slick-cloned',
#    'aria-hidden': 'true'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'class': 'c5HdF',
#    'style': 'width:100%;display:inline-block',
#    'tabindex': '-1'}},
#  {'tag': 'div',
#   'attributes': {'style': 'width:113 px',
#    'data-index': '15',
#    'tabindex': '-1',
#    'class': 'slick-slide slick-cloned',
#    'aria-hidden': 'true'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'class': 'c5HdF',
#    'style': 'width:100%;display:inline-block',
#    'tabindex': '-1'}},
#  {'tag': 'div',
#   'attributes': {'style': 'width:116 px',
#    'data-index': '16',
#    'tabindex': '-1',
#    'class': 'slick-slide slick-cloned',
#    'aria-hidden': 'true'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'class': 'c5HdF',
#    'style': 'width:100%;display:inline-block',
#    'tabindex': '-1'}},
#  {'tag': 'div',
#   'attributes': {'style': 'width:114 px',
#    'data-index': '17',
#    'tabindex': '-1',
#    'class': 'slick-slide slick-cloned',
#    'aria-hidden': 'true'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'class': 'c5HdF',
#    'style': 'width:100%;display:inline-block',
#    'tabindex': '-1'}},
#  {'tag': 'div',
#   'attributes': {'style': 'width:123 px',
#    'data-index': '18',
#    'tabindex': '-1',
#    'class': 'slick-slide slick-cloned',
#    'aria-hidden': 'true'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'class': 'c5HdF',
#    'style': 'width:100%;display:inline-block',
#    'tabindex': '-1'}},
#  {'tag': 'div',
#   'attributes': {'style': 'width:111 px',
#    'data-index': '19',
#    'tabindex': '-1',
#    'class': 'slick-slide slick-cloned',
#    'aria-hidden': 'true'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'class': 'c5HdF',
#    'style': 'width:100%;display:inline-block',
#    'tabindex': '-1'}},
#  {'tag': 'div', 'attributes': {'class': 'pZFl7'}},
#  {'tag': 'div', 'attributes': {'class': 't8vf3 byline_action'}},
#  {'tag': 'div', 'attributes': {'class': 'xf8Pm byline'}},
#  {'tag': 'div',
#   'attributes': {'class': 'eg6hg', 'data-socialshare': '107051526'}},
#  {'tag': 'div', 'attributes': {'class': 'okf2Z'}},
#  {'tag': 'div', 'attributes': {'class': 'nSsMM '}},
#  {'tag': 'div',
#   'attributes': {'data-socialshare': '107051526', 'class': 'tp_widget_as'}},
#  {'tag': 'div', 'attributes': {'class': 'xCgxU QNWRv    aODZq'}},
#  {'tag': 'div', 'attributes': {'class': 'CfcTh icon_share_wrap'}},
#  {'tag': 'div', 'attributes': {'class': 'LaAfQ'}},
#  {'tag': 'div', 'attributes': {'class': 'MRCIT '}},
#  {'tag': 'div', 'attributes': {'class': 's9FOM'}},
#  {'tag': 'div', 'attributes': {'class': 'undefined V5EgZ'}},
#  {'tag': 'div', 'attributes': {'class': 'clearfix'}},
#  {'tag': 'div', 'attributes': {'class': 'JuyWl'}},
#  {'tag': 'div', 'attributes': {'class': 'NXrRQ'}},
#  {'tag': 'div',
#   'attributes': {'class': 'persObserver personaliseWidgetLoader_107051526 elU3m iTamo cB36u',
#    'data-card': 'upNext',
#    'data-heading': '',
#    'data-section': 'Sports',
#    'data-subsection': 'Cricket',
#    'id': 'upNext_107051526',
#    'data-msid': '107051526',
#    'data-template': 'AS',
#    'data-contentprimestatus': 'non-prime',
#    'data-userprimestatus': 'non-prime',
#    'style': 'min-height:550px;position:sticky',
#    'data-translate-sticky': '100'}},
#  {'tag': 'div', 'attributes': {'id': 'astro_talk_nudge'}},
#  {'tag': 'div', 'attributes': {'class': 'vSlIC  '}},
#  {'tag': 'div', 'attributes': {'class': 'heightCalc'}},
#  {'tag': 'div', 'attributes': {'class': 'art_synopsis'}},
#  {'tag': 'div', 'attributes': {'data-type': 'in_view', 'class': '  '}},
#  {'tag': 'div', 'attributes': {'class': 'tCKCr  id-r-synopsis'}},
#  {'tag': 'div', 'attributes': {'class': 'faiOF'}},
#  {'tag': 'div', 'attributes': {'class': 'WEwSo'}},
#  {'tag': 'div', 'attributes': {'class': 'M1rHh undefined'}},
#  {'tag': 'div',
#   'attributes': {'data-articlebody': '1', 'class': 'fewcent-107051526'}},
#  {'tag': 'div', 'attributes': {'class': 'T22zO'}},
#  {'tag': 'div', 'attributes': {'class': 'D3Wk1'}},
#  {'tag': 'div', 'attributes': {'class': 'zPaFh '}},
#  {'tag': 'div', 'attributes': {'class': 'wJnIp'}},
#  {'tag': 'div', 'attributes': {'class': 'cj2hz img_cptn'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div', 'attributes': {'class': '_s30J clearfix  '}},
#  {'tag': 'div',
#   'attributes': {'class': 'persObserver personaliseWidgetLoader_107051526 elU3m iTamo undefined',
#    'data-card': 'readAlso',
#    'data-heading': '',
#    'data-section': 'Sports',
#    'data-subsection': 'Cricket',
#    'id': 'readAlso_107051526',
#    'data-msid': '107051526',
#    'data-template': 'AS',
#    'data-contentprimestatus': 'non-prime',
#    'data-userprimestatus': 'non-prime',
#    'style': 'min-height:330.06px'}},
#  {'tag': 'div', 'attributes': {'class': 'mgid_second_mrec_parent'}},
#  {'tag': 'div',
#   'attributes': {'class': 'wdt-taboola',
#    'data-mode': 'thumbnails-mid',
#    'data-target_type': 'mix',
#    'style': 'max-height:415px;overflow:hidden',
#    'id': 'taboola-mid-article-thumbnails-107051526',
#    'data-placement': 'Mid Article Thumbnails 1'}},
#  {'tag': 'div',
#   'attributes': {'data-type': 'in_view', 'class': '  plcTwttr socialembed'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div', 'attributes': {'class': 'lOvcW'}},
#  {'tag': 'div', 'attributes': {'class': 'ge4Md', 'style': 'min-height:290px'}},
#  {'tag': 'div',
#   'attributes': {'data-type': 'in_view', 'class': 'loadable-inview  '}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div', 'attributes': {'class': 'OtxlN', 'id': 'auhtor_widget'}},
#  {'tag': 'div', 'attributes': {'class': 'Mn6kH'}},
#  {'tag': 'div',
#   'attributes': {'data-pos': '0',
#    'class': 'id-r-component QbQNS undefined  \n        '}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div', 'attributes': {'class': 'f2VrG'}},
#  {'tag': 'div', 'attributes': {'class': 'kgcOp'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div', 'attributes': {'class': 'GE1a7 oJgW0 '}},
#  {'tag': 'div', 'attributes': {'class': ''}},
#  {'tag': 'div', 'attributes': {'class': 'ge4Md', 'style': 'min-height:75px'}},
#  {'tag': 'div',
#   'attributes': {'data-type': 'in_view', 'class': 'loadable-inview  '}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div', 'attributes': {'class': '_MxBD'}},
#  {'tag': 'div',
#   'attributes': {'class': 'wdt-taboola',
#    'data-mode': 'thumbnails-below',
#    'data-target_type': 'mix',
#    'id': 'taboola-below-article-thumbnails-107051526',
#    'data-placement': 'Below Article Thumbnails 1'}},
#  {'tag': 'div',
#   'attributes': {'class': 'persObserver personaliseWidgetLoader_107051526 elU3m iTamo xkbsB',
#    'data-card': 'readNextColumnVariant',
#    'data-heading': '',
#    'data-section': 'Sports',
#    'data-subsection': 'Cricket',
#    'id': 'readNextColumnVariant_107051526',
#    'data-msid': '107051526',
#    'data-template': 'AS',
#    'data-contentprimestatus': 'non-prime',
#    'data-userprimestatus': 'non-prime',
#    'style': 'min-height:356px'}},
#  {'tag': 'div',
#   'attributes': {'class': 'XAt75', 'data-bottomsocialshare': '107051526'}},
#  {'tag': 'div', 'attributes': {'class': 'ge4Md', 'style': 'min-height:24px'}},
#  {'tag': 'div',
#   'attributes': {'data-type': 'in_view', 'class': 'loadable-inview  '}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div', 'attributes': {'class': ''}},
#  {'tag': 'div', 'attributes': {'class': 'visualstoriesas_wrapper'}},
#  {'tag': 'div', 'attributes': {'data-type': 'in_view', 'class': '  '}},
#  {'tag': 'div', 'attributes': {'class': 'nXGto'}},
#  {'tag': 'div', 'attributes': {'data-type': 'in_view', 'class': '  '}},
#  {'tag': 'div', 'attributes': {'class': 'OWwCd'}},
#  {'tag': 'div', 'attributes': {'class': 'EIMcv'}},
#  {'tag': 'div', 'attributes': {'class': 'slick_UI'}},
#  {'tag': 'div',
#   'attributes': {'class': 'slick-slider slick-initialized', 'dir': 'ltr'}},
#  {'tag': 'div', 'attributes': {'class': 'slick-list'}},
#  {'tag': 'div',
#   'attributes': {'class': 'slick-track', 'style': 'width:250%;left:0%'}},
#  {'tag': 'div',
#   'attributes': {'data-index': '0',
#    'class': 'slick-slide slick-active slick-current',
#    'tabindex': '-1',
#    'aria-hidden': 'false',
#    'style': 'outline:none;width:10%'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'tabindex': '-1',
#    'style': 'width:100%;display:inline-block'}},
#  {'tag': 'div', 'attributes': {'class': 'yYYj5'}},
#  {'tag': 'div', 'attributes': {'class': 'aTQlg'}},
#  {'tag': 'div', 'attributes': {'class': 'gycE5'}},
#  {'tag': 'div',
#   'attributes': {'data-index': '1',
#    'class': 'slick-slide slick-active',
#    'tabindex': '-1',
#    'aria-hidden': 'false',
#    'style': 'outline:none;width:10%'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'tabindex': '-1',
#    'style': 'width:100%;display:inline-block'}},
#  {'tag': 'div', 'attributes': {'class': 'yYYj5'}},
#  {'tag': 'div', 'attributes': {'class': 'aTQlg'}},
#  {'tag': 'div', 'attributes': {'class': 'gycE5'}},
#  {'tag': 'div',
#   'attributes': {'data-index': '2',
#    'class': 'slick-slide slick-active',
#    'tabindex': '-1',
#    'aria-hidden': 'false',
#    'style': 'outline:none;width:10%'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'tabindex': '-1',
#    'style': 'width:100%;display:inline-block'}},
#  {'tag': 'div', 'attributes': {'class': 'yYYj5'}},
#  {'tag': 'div', 'attributes': {'class': 'aTQlg'}},
#  {'tag': 'div', 'attributes': {'class': 'gycE5'}},
#  {'tag': 'div',
#   'attributes': {'data-index': '3',
#    'class': 'slick-slide slick-active',
#    'tabindex': '-1',
#    'aria-hidden': 'false',
#    'style': 'outline:none;width:10%'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'tabindex': '-1',
#    'style': 'width:100%;display:inline-block'}},
#  {'tag': 'div', 'attributes': {'class': 'yYYj5'}},
#  {'tag': 'div', 'attributes': {'class': 'aTQlg'}},
#  {'tag': 'div', 'attributes': {'class': 'gycE5'}},
#  {'tag': 'div',
#   'attributes': {'data-index': '4',
#    'class': 'slick-slide',
#    'tabindex': '-1',
#    'aria-hidden': 'true',
#    'style': 'outline:none;width:10%'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'tabindex': '-1',
#    'style': 'width:100%;display:inline-block'}},
#  {'tag': 'div', 'attributes': {'class': 'yYYj5'}},
#  {'tag': 'div', 'attributes': {'class': 'aTQlg'}},
#  {'tag': 'div', 'attributes': {'class': 'gycE5'}},
#  {'tag': 'div',
#   'attributes': {'data-index': '5',
#    'class': 'slick-slide',
#    'tabindex': '-1',
#    'aria-hidden': 'true',
#    'style': 'outline:none;width:10%'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'tabindex': '-1',
#    'style': 'width:100%;display:inline-block'}},
#  {'tag': 'div', 'attributes': {'class': 'yYYj5'}},
#  {'tag': 'div', 'attributes': {'class': 'aTQlg'}},
#  {'tag': 'div', 'attributes': {'class': 'gycE5'}},
#  {'tag': 'div',
#   'attributes': {'data-index': '6',
#    'class': 'slick-slide',
#    'tabindex': '-1',
#    'aria-hidden': 'true',
#    'style': 'outline:none;width:10%'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'tabindex': '-1',
#    'style': 'width:100%;display:inline-block'}},
#  {'tag': 'div', 'attributes': {'class': 'yYYj5'}},
#  {'tag': 'div', 'attributes': {'class': 'aTQlg'}},
#  {'tag': 'div', 'attributes': {'class': 'gycE5'}},
#  {'tag': 'div',
#   'attributes': {'data-index': '7',
#    'class': 'slick-slide',
#    'tabindex': '-1',
#    'aria-hidden': 'true',
#    'style': 'outline:none;width:10%'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'tabindex': '-1',
#    'style': 'width:100%;display:inline-block'}},
#  {'tag': 'div', 'attributes': {'class': 'yYYj5'}},
#  {'tag': 'div', 'attributes': {'class': 'aTQlg'}},
#  {'tag': 'div', 'attributes': {'class': 'gycE5'}},
#  {'tag': 'div',
#   'attributes': {'data-index': '8',
#    'class': 'slick-slide',
#    'tabindex': '-1',
#    'aria-hidden': 'true',
#    'style': 'outline:none;width:10%'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'tabindex': '-1',
#    'style': 'width:100%;display:inline-block'}},
#  {'tag': 'div', 'attributes': {'class': 'yYYj5'}},
#  {'tag': 'div', 'attributes': {'class': 'aTQlg'}},
#  {'tag': 'div', 'attributes': {'class': 'gycE5'}},
#  {'tag': 'div',
#   'attributes': {'data-index': '9',
#    'class': 'slick-slide',
#    'tabindex': '-1',
#    'aria-hidden': 'true',
#    'style': 'outline:none;width:10%'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'tabindex': '-1',
#    'style': 'width:100%;display:inline-block'}},
#  {'tag': 'div', 'attributes': {'class': 'yYYj5'}},
#  {'tag': 'div', 'attributes': {'class': 'aTQlg'}},
#  {'tag': 'div', 'attributes': {'class': 'gycE5'}},
#  {'tag': 'div', 'attributes': {'data-type': 'in_view', 'class': '  '}},
#  {'tag': 'div',
#   'attributes': {'class': 'd4Mxk undefined articletrendinglistwrapper',
#    'id': ''}},
#  {'tag': 'div', 'attributes': {'class': 'whlbt articletrendinglist '}},
#  {'tag': 'div',
#   'attributes': {'class': 'slick-slider slider variable-width slick-initialized',
#    'dir': 'ltr'}},
#  {'tag': 'div', 'attributes': {'class': 'slick-list'}},
#  {'tag': 'div',
#   'attributes': {'class': 'slick-track', 'style': 'width:0px;left:0px'}},
#  {'tag': 'div',
#   'attributes': {'style': 'outline:none',
#    'data-index': '0',
#    'class': 'slick-slide slick-active slick-current',
#    'tabindex': '-1',
#    'aria-hidden': 'false'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'style': 'outline:none',
#    'data-index': '1',
#    'class': 'slick-slide',
#    'tabindex': '-1',
#    'aria-hidden': 'true'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'style': 'outline:none',
#    'data-index': '2',
#    'class': 'slick-slide',
#    'tabindex': '-1',
#    'aria-hidden': 'true'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'style': 'outline:none',
#    'data-index': '3',
#    'class': 'slick-slide',
#    'tabindex': '-1',
#    'aria-hidden': 'true'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'style': 'outline:none',
#    'data-index': '4',
#    'class': 'slick-slide',
#    'tabindex': '-1',
#    'aria-hidden': 'true'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'style': 'outline:none',
#    'data-index': '5',
#    'class': 'slick-slide',
#    'tabindex': '-1',
#    'aria-hidden': 'true'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div', 'attributes': {'data-type': 'in_view', 'class': '  '}},
#  {'tag': 'div',
#   'attributes': {'class': 'd4Mxk undefined articletrendinglistwrapper',
#    'id': ''}},
#  {'tag': 'div', 'attributes': {'class': 'whlbt articletrendinglist '}},
#  {'tag': 'div',
#   'attributes': {'class': 'slick-slider slider variable-width slick-initialized',
#    'dir': 'ltr'}},
#  {'tag': 'div', 'attributes': {'class': 'slick-list'}},
#  {'tag': 'div',
#   'attributes': {'class': 'slick-track', 'style': 'width:0px;left:0px'}},
#  {'tag': 'div',
#   'attributes': {'style': 'outline:none',
#    'data-index': '0',
#    'class': 'slick-slide slick-active slick-current',
#    'tabindex': '-1',
#    'aria-hidden': 'false'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'style': 'outline:none',
#    'data-index': '1',
#    'class': 'slick-slide',
#    'tabindex': '-1',
#    'aria-hidden': 'true'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'style': 'outline:none',
#    'data-index': '2',
#    'class': 'slick-slide',
#    'tabindex': '-1',
#    'aria-hidden': 'true'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'style': 'outline:none',
#    'data-index': '3',
#    'class': 'slick-slide',
#    'tabindex': '-1',
#    'aria-hidden': 'true'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'style': 'outline:none',
#    'data-index': '4',
#    'class': 'slick-slide',
#    'tabindex': '-1',
#    'aria-hidden': 'true'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'style': 'outline:none',
#    'data-index': '5',
#    'class': 'slick-slide',
#    'tabindex': '-1',
#    'aria-hidden': 'true'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'style': 'outline:none',
#    'data-index': '6',
#    'class': 'slick-slide',
#    'tabindex': '-1',
#    'aria-hidden': 'true'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'style': 'outline:none',
#    'data-index': '7',
#    'class': 'slick-slide',
#    'tabindex': '-1',
#    'aria-hidden': 'true'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'style': 'outline:none',
#    'data-index': '8',
#    'class': 'slick-slide',
#    'tabindex': '-1',
#    'aria-hidden': 'true'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div',
#   'attributes': {'style': 'outline:none',
#    'data-index': '9',
#    'class': 'slick-slide',
#    'tabindex': '-1',
#    'aria-hidden': 'true'}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div', 'attributes': {'class': 'eTaBv article_rhs Sports '}},
#  {'tag': 'div',
#   'attributes': {'data-mod': 'sidebar',
#    'data-sidebartheme': 'default',
#    'class': '_AmfD sidebar_ad_fix'}},
#  {'tag': 'div', 'attributes': {'class': '_Puhr paisa-wrapper'}},
#  {'tag': 'div',
#   'attributes': {'id': 'div-gpt-ad-1416990040345-7b3398dd-3743-4740-b4a5-10c71a01ea4e-107051526-1',
#    'class': 'MzKhO  undefined'}},
#  {'tag': 'div', 'attributes': {'class': 'adplaceholder'}},
#  {'tag': 'div',
#   'attributes': {'data-type': 'in_view', 'class': 'loadable-inview  '}},
#  {'tag': 'div', 'attributes': {'class': 'relatedVideoWrapper'}},
#  {'tag': 'div', 'attributes': {'class': '_Puhr paisa-wrapper'}},
#  {'tag': 'div',
#   'attributes': {'id': 'div-gpt-ad-1416990040345-9fc74cf1-ad98-4775-b4bb-1de48d680d70-107051526-1',
#    'class': 'MzKhO  undefined'}},
#  {'tag': 'div', 'attributes': {'class': 'adplaceholder'}},
#  {'tag': 'div', 'attributes': {'data-type': 'in_view', 'class': '  '}},
#  {'tag': 'div', 'attributes': {'class': 'ISnJ7'}},
#  {'tag': 'div', 'attributes': {'class': 'kqWjC'}},
#  {'tag': 'div', 'attributes': {'class': 'ZHgwH'}},
#  {'tag': 'div', 'attributes': {'class': 'qbyLk yWihP'}},
#  {'tag': 'div', 'attributes': {'class': 'qbyLk '}},
#  {'tag': 'div', 'attributes': {'class': '_Puhr paisa-wrapper'}},
#  {'tag': 'div',
#   'attributes': {'id': 'div-gpt-ad-1416990040345-e9f286d8-ddcd-4e0e-a9ef-9a9f2dac93bc-107051526-1',
#    'class': 'MzKhO  undefined'}},
#  {'tag': 'div', 'attributes': {'class': 'adplaceholder'}},
#  {'tag': 'div', 'attributes': {'class': 'imageBanner'}},
#  {'tag': 'div', 'attributes': {'data-type': 'in_view', 'class': '  '}},
#  {'tag': 'div', 'attributes': {'class': 'i9Tq4 undefined'}},
#  {'tag': 'div', 'attributes': {'class': 'DzUVR'}},
#  {'tag': 'div', 'attributes': {'class': '_Puhr paisa-wrapper'}},
#  {'tag': 'div',
#   'attributes': {'id': 'div-gpt-ad-1533900544881-6d195ed2-f2b6-47da-b138-952b89eeb2df-107051526-1',
#    'class': 'MzKhO  undefined'}},
#  {'tag': 'div', 'attributes': {'class': 'adplaceholder'}},
#  {'tag': 'div', 'attributes': {'class': 'undefined LSrFq ddjHc'}},
#  {'tag': 'div', 'attributes': {'id': 'affiliate_non_msp_rhs_widget'}},
#  {'tag': 'div', 'attributes': {'data-type': 'in_view', 'class': '  '}},
#  {'tag': 'div',
#   'attributes': {'data-aff-type': 'aff-content',
#    'data-aff-version': 'v2',
#    'class': 'D7ys0'}},
#  {'tag': 'div', 'attributes': {'class': '_Puhr paisa-wrapper'}},
#  {'tag': 'div',
#   'attributes': {'id': 'div-gpt-ad-1533710578908-e697bdd0-0bc3-42d1-adbc-68f000b751be-107051526-1',
#    'class': 'MzKhO  undefined'}},
#  {'tag': 'div', 'attributes': {'class': 'adplaceholder'}},
#  {'tag': 'div', 'attributes': {'id': 'liner-107051526'}},
#  {'tag': 'div', 'attributes': {'class': 'undefined clearfix'}},
#  {'tag': 'div', 'attributes': {'class': 'undefined '}},
#  {'tag': 'div', 'attributes': {}},
#  {'tag': 'div', 'attributes': {'id': 'comment-sidebar-107051526'}},
#  {'tag': 'div', 'attributes': {'data-articlepage-end': '107051526'}},
#  {'tag': 'div',
#   'attributes': {'id': 'toi-article-container-100243456',
#    'class': 'clearfix rel'}},
#  {'tag': 'div', 'attributes': {'class': 'perpetual'}},
#  {'tag': 'div',
#   'attributes': {'id': 'next-story-107051526',
#    'data-linkindex': '0',
#    'data-prevlinkindex': '-2'}},
#  {'tag': 'div',
#   'attributes': {'id': 'toi-article-container-107046228',
#    'class': 'clearfix rel'}},
#  {'tag': 'div', 'attributes': {'class': 'perpetual'}},
#  {'tag': 'div',
#   'attributes': {'id': 'next-story-100243456',
#    'data-linkindex': '1',
#    'data-prevlinkindex': '-1'}},
#  {'tag': 'div',
#   'attributes': {'id': 'toi-article-container-107040105',
#    'class': 'clearfix rel'}},
#  {'tag': 'div', 'attributes': {'class': 'perpetual'}},
#  {'tag': 'div',
#   'attributes': {'id': 'next-story-107046228',
#    'data-linkindex': '2',
#    'data-prevlinkindex': '0'}},
#  {'tag': 'div',
#   'attributes': {'id': 'next-story-107040105',
#    'data-linkindex': '3',
#    'data-prevlinkindex': '1',
#    'style': 'display:none'}},
#  {'tag': 'div',
#   'attributes': {'data-translate-id': 'cw',
#    'class': 'X2plK footer_wrapper contentwrapper '}},
#  {'tag': 'div', 'attributes': {'class': 'contentwrapper'}},
#  {'tag': 'div', 'attributes': {'class': 'VRKZ3'}},
#  {'tag': 'div', 'attributes': {'class': 'D9RyY'}},
#  {'tag': 'div', 'attributes': {'class': 'LazyLoad', 'style': 'height:1px'}},
#  {'tag': 'div', 'attributes': {'class': 'undefined'}},
#  {'tag': 'div', 'attributes': {'class': 'YYaA9'}},
#  {'tag': 'div', 'attributes': {'data-type': 'in_view', 'class': '  '}},
#  {'tag': 'div', 'attributes': {'class': 'social_footer_heading'}},
#  {'tag': 'div', 'attributes': {'class': 'undefined'}},
#  {'tag': 'div', 'attributes': {'class': 'YYaA9'}},
#  {'tag': 'div', 'attributes': {'class': 'wvELk'}},
#  {'tag': 'div', 'attributes': {'class': 'undefined'}},
#  {'tag': 'div', 'attributes': {'class': 'YYaA9'}},
#  {'tag': 'div', 'attributes': {'class': 'undefined'}},
#  {'tag': 'div', 'attributes': {'class': 'YYaA9'}},
#  {'tag': 'div', 'attributes': {'class': 'undefined'}},
#  {'tag': 'div', 'attributes': {'class': 'YYaA9'}},
#  {'tag': 'div', 'attributes': {'class': 'undefined'}},
#  {'tag': 'div', 'attributes': {'class': 'YYaA9'}},
#  {'tag': 'div', 'attributes': {'class': 'undefined'}},
#  {'tag': 'div', 'attributes': {'class': 'YYaA9'}},
#  {'tag': 'div', 'attributes': {'class': 'undefined'}},
#  {'tag': 'div', 'attributes': {'class': 'YYaA9'}},
#  {'tag': 'div', 'attributes': {'class': 'VRKZ3 vS2n1'}},
#  {'tag': 'div', 'attributes': {'class': 'undefined'}},
#  {'tag': 'div', 'attributes': {'class': 'YYaA9'}},
#  {'tag': 'div', 'attributes': {'class': 'nVZnl'}},
#  {'tag': 'div',
#   'attributes': {'id': 'div-gpt-ad-1357881512803-4b9fa9a0-42ab-4ae6-8c53-84641f9370ea-1',
#    'class': 'Y4_Am '}}]

# %%
from lxmlparser1 import HTMLParser

parser = HTMLParser(response.text)
nodes = nodes_to_check(parser,soup)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_32679/2288446678.py in <module>
#       2
#       3 parser = HTMLParser(response.text)
# ----> 4 nodes = nodes_to_check(parser,soup)
#
# NameError: name 'nodes_to_check' is not defined

# %%
print(type(nodes[0]))
# Out:
# <class 'dict'>

# %%
def get_stopword_count(text):
        text = re.sub(r'[^\w\s]', '', text)
        words = [word.lower() for word in text.split()]

        sm = 0
        for word in words:
          if(word in stop_words):
            sm+=1
        return sm

# %%
nodes_with_text = []
for node in nodes:
            try:
                text_node = parser.get_text_by_tag(tag_name=node['tag'], attribute_name='class', attribute_value=node['attributes']['class'])
            except:
                text_node = parser.get_text_by_tag(tag_name=node['tag'])
#             print(text_node)
            result_string = ' '.join(text_node)
            word_stats = get_stopword_count(result_string)
# #             print(node.get_text(strip=True))
#             high_link_density = self.is_highlink_density(node)
            if word_stats >= 15:
                nodes_with_text.append(node)

#             print(result_string)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_32679/507370815.py in <module>
#       1 nodes_with_text = []
# ----> 2 for node in nodes:
#       3             try:
#       4                 text_node = parser.get_text_by_tag(tag_name=node['tag'], attribute_name='class', attribute_value=node['attributes']['class'])
#       5             except:
#
# NameError: name 'nodes' is not defined

# %%
print((nodes_with_text))
# Out:
# []

# %%
def get_text(node):
    try:
                    text_node = parser.get_text_by_tag(tag_name=node['tag'], attribute_name='class', attribute_value=node['attributes']['class'])
    except:
                    text_node = parser.get_text_by_tag(tag_name=node['tag'])
    #             print(text_node)
    result_string = ''.join(text_node)
    clean_string = re.sub(r'[\n\t]', '', result_string)
#     print(clean_string)
    return clean_string

def get_text_reg(node):
    try:
                    text_node = parser.get_text_by_tag(tag_name=node['tag'], attribute_name='class', attribute_value=node['attributes']['class'])
    except:
                    text_node = parser.get_text_by_tag(tag_name=node['tag'])
    #             print(text_node)
    result_string = ''.join(text_node)
    return result_string

# %%
def nodes_to_check(self, soup):
    nodes_to_chec = []
    for tag in ['div','p', 'pre', 'td']:
        # items = soup.find_all(tag)
        items = self.find_all_tags(tag_name = tag)
        nodes_to_chec += items

#        print(nodes_to_check)
    return nodes_to_chec

def update_score(node, score):
    if 'score' not in node.keys():
        try:
            node['score'] = len(get_text(node))**(0.5)
        except:
            node['score'] = 0
    node['score'] += score

def get_score(node):
    update_score(node, 0)
    return node['score']

# %%
def get_parent(node):
    try:

            text_node = parser.parent(tag_name=node['tag'], attribute_name='class', attribute_value=node['attributes']['class'])
            return text_node
    except:
            try:
                text_node = parser.parent(tag_name=node['tag'])
                return text_node
            except:
                return None

# %%
parent_nodes = []
top_node = -1
top_node_score = -1
mx = -1
if(1):
    if(1):

        for node in nodes_with_text:
#             boost_score = len(node.find_all('p'))


            try:
                boost_score, depth = count_paragraph_tags_on_same_level_with_depth(node)
    #                print(node['class'], " ", boost_score)
            except:
                boost_score,depth = 0,0


#             text_node =get_text(node)
            text_node = get_text(node)
            word_stats = get_stopword_count(get_text_reg(node))/2

            temp = 0

            try:
                temp = len(node.content)
            except:
                pass

            boost_score = boost_score*(0.95**(depth+1))
            upscore = word_stats + boost_score



            parent_node = get_parent(node)[0]

            update_score(node,upscore)

#             print(node.name," ",word_stats," ",boost_score," ",node['score']," ",upscore)

            x = node
#             print(parent_node)
#             if(x['tag'] == 'p'):
#                 for i in range(5):
#                     try:
#                         x = parser.parent(x['tag'],'class',x['attributes']['class'])
#                         update_score(x,upscore*((0.8)**i))
#                     except:
#                         break

            if parent_node not in parent_nodes:
                parent_nodes.append(parent_node)

            parent_parent_node = None
            if parent_parent_node is not None:
                parent_parent_node = get_parent(parent_node)[0]
#                 self.update_node_count(parent_parent_node, 1)

                if parent_parent_node not in parent_nodes:
                    parent_nodes.append(parent_parent_node)
#             cnt += 1
#             i += 1

        parent_nodes.append(node)

        for e in parent_nodes:
#                 print(type(e))
            try:
                score = get_score(e)
                print(score)
                if score > top_node_score:
    #                 print(node.name," ",node['score'])
                    top_node = e
                    top_node_score = score

                if top_node is None:
                    top_node = e
            except:
                continue
        print(top_node)


#             temp = 0
# #             try:
# #                 temp = len(node.content)
# #             except:
# #                 pass
# #             upscore = word_stats**(0.2) + 0 - abs((temp - 3*0))**0.25

#             if('class' in node['attributes']):
#                     print(node['attributes']['class'])
#             print(word_stats**(0.5)," ",upscore)
#             if(word_stats > mx):
#                 mx = word_stats
#                 best_node = node

# #             parent_node = node.parent
#             update_score(node,upscore)

#             x = node
#             if(x['tag'] == 'p'):
#                 for i in range(5):
#                     try:
#                         x = parser.parent(x['tag'],'class',x['attributes']['class'])
#                         update_score(x,upscore*((0.8)**i))
#                     except:
#                         break

# #             if parent_node not in parent_nodes:
# #                 parent_nodes.append(parent_node)

# #             parent_parent_node = parent_node.parent
# #             if parent_parent_node is not None:
# #                 self.update_node_count(parent_parent_node, 1)

# #                 if parent_parent_node not in parent_nodes:
# #                     parent_nodes.append(parent_parent_node)
# #             cnt += 1
# #             i += 1


# #         for e in parent_nodes:
# #             score = self.get_score(e)

# #             if score > top_node_score:
# #     #                print(node.name," ",node['score'])
# #                 top_node = e
# #                 top_node_score = score

# #             if top_node is None:
# #                 top_node = e
# #         return top_node

print(get_text(top_node))
# Out:
# 387.52654763307254
# {'tag': 'div', 'attributes': {'id': 'next-story-108134071', 'data-linkindex': '3', 'data-prevlinkindex': '1', 'style': 'display:none'}, 'score': 387.52654763307254}
# EditionININUSSign InTOIAutoCarsVideosNewsBikesElectric CarElectric BikeProduct & PolicyLaunchesReviewsAdvice centreCommercial vehiclesMotorsportsFaceoffsWeb StoriesToday's ePaperNewsAuto NewsCars NewsHyundai sells 60,501 units in Feb: Records highest-ever Creta sales, SUV contribution nearly two-thirdTrendingMahindra TharAther Rizta Electric ScooterVinfast Electric VehicleBydHyundai CretaMorth AdvisoryPowerful Turbo Petrol CarsHighest Selling SedansMahindra TharAther Rizta Electric ScooterVinfast Electric VehicleBydHyundai CretaMorth AdvisoryPowerful Turbo Petrol CarsHighest Selling SedansMahindra TharAther Rizta Electric ScooterVinfast Electric VehicleBydHyundai CretaMorth AdvisoryPowerful Turbo Petrol CarsHighest Selling SedansHyundai sells 60,501 units in Feb: Records highest-ever Creta sales, SUV contribution nearly two-thirdYash Sharma / TIMESOFINDIA.COM /  Mar 2, 2024, 12:47 ISTShareAA+Text SizeSmallMediumLargeFollow us Hyundai Motor India recorded 6.8% growth in domestic sales with the 2024 Creta achieving its highest-ever sales. SUVs contributed 67% to overall sales. The company plans to expand production capacity and make progress in the EV segment with ultra-fast chargers. Hyundai sells 60,501 units in Feb: Records highest-ever Creta sales, SUV contribution nearly two-third Hyundai Motor India sold 60,501 units in February 2024. Of this, domestic sales stood at 50,201 units, marking a notable 6.8 percent growth compared to the previous year. Exports, on the other hand, stood at 10,300 units. Hyundai Feb Sales: SUVs lead the chargeIt is interesting to note that in the first full month since the launch of the 2024 Creta, the SUV has clocked 15,276 units, the highest-ever sales recorded for the Creta model since its debut in 2015.Tarun Garg, COO, Hyundai India, highlighted the significant contribution of the SUV segment to the company's overall sales performance.Against the industry average of 52% SUV sales in India, Hyundai boasts an impressive 67% SUV sales figure in the ongoing financial year. Over the past two months, SUVs have constituted 64 percent of Hyundai's sales, demonstrating their substantial popularity. In fact, the SUV contribution for HMSI has been at 67 percent in the ongoing financial year, significantly higher than the industry average of 52 percent. The company aims to maintain this trend, targeting a year-end SUV sales figure of 65 percent.Hyundai Feb Sales: Why SUVs are becoming popular in the company’s lineupIn addressing TOI Auto's query regarding the surging popularity of SUVs, Garg highlighted that the company offers products across every segment, with notable success seen in the entry-level Exter, which has doubled the contribution of its respective segment.Hyundai Exter meets Tiger: Great India Drive 2023 | TOI Auto“Our focus remains on setting benchmarks with standard features like six airbags in the Exter model,” explained Garg. The company had also integrated dash cameras into the entry-level segment as part of its broader strategy. Additionally, the Creta has become the sixth Hyundai model to feature Advanced Driver Assistance Systems (ADAS). Sunroofs are also a sought-after feature in Hyundai SUVs. In a gist, the company has bolstered its presence and stimulated SUV sales by expanding its offerings across all segments and prioritizing features and safety.Hyundai Feb Sales: Highest-ever rural penetrationFurthermore, with rural penetration crossing 20 percent for the first time in February, HMIL is experiencing a balanced sales distribution between urban and rural areas, thanks to improved road infrastructure and connectivity.Looking ahead, HMIL aims to address the growing demand with plans to expand production capacity. With a booking backlog of 85,000 to 100,000 units over the past five months, Hyundai's Pune plant is expected to add 150,000 units, bringing total capacity to 1 million units in the mid-term.Additionally, HMIL is making strides in the electric vehicle (EV) segment, with in ...

# %%
print(top_node)
# Out:
# {'tag': 'p', 'attributes': {}, 'score': 84.98509786706248}

# %%
# for node in nodes_to_check:
#             text_node = node.get_text()
#             word_stats = self.get_stopword_count(text_node)
# #             print(node.get_text(strip=True))
#             high_link_density = self.is_highlink_density(node)
#             if word_stats >= 5 and not high_link_density:
#                 nodes_with_text.append(node)

#         nodes_number = len(nodes_with_text)
#         negative_scoring = 0
#         bottom_negativescore_nodes = nodes_number * 0.25

# #         print(nodes_with_text)
#         for node in nodes_with_text:

# #             print(type(node))

#             try:
#                 boost_score, depth = count_paragraph_tags_on_same_level_with_depth(node)
#     #                print(node['class'], " ", boost_score)
#             except:
#                 boost_score = 0



#             text_node = node.get_text(strip=True)
#             word_stats = self.get_stopword_count(text_node)/2
#             temp = 0

#             try:
#                 temp = len(node.content)
#             except:
#                 pass

#             boost_score = boost_score*(0.95**(depth+1))
#             upscore = word_stats + boost_score

# #             print(upscore," ",word_stats," ",boost_score," ",word_stats+boost_score)

# #             if(node.has_attr('class')):
# #                 print(node['class'])


#             parent_node = node.parent
#             self.update_score(node,upscore)




# #             print(node.name," ",word_stats," ",boost_score," ",node['score']," ",upscore)

#             x = node
#             if(node.name == 'p'):
#                 for i in range(5):
#                     x = x.parent
#                     self.update_score(x,upscore*((0.8)**i))

#             if parent_node not in parent_nodes:
#                 parent_nodes.append(parent_node)

#             parent_parent_node = parent_node.parent
#             if parent_parent_node is not None:
#                 self.update_node_count(parent_parent_node, 1)

#                 if parent_parent_node not in parent_nodes:
#                     parent_nodes.append(parent_parent_node)
#             cnt += 1
#             i += 1

#         parent_nodes.append(node)

#         for e in parent_nodes:
#             score = self.get_score(e)

#             if score > top_node_score:
# #                 print(node.name," ",node['score'])
#                 top_node = e
#                 top_node_score = score

#             if top_node is None:
#                 top_node = e

#         return top_node

# %%
for node in nodes_with_text:
    print(node,node['score'])
# Out:
# {'tag': 'div', 'attributes': {'id': 'TOI_appgutter_left'}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'id': 'TOI_appgutter_right'}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'id': 'app'}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'class': 'nonAppView layout_type_2', 'data-reactroot': ''}, 'score': 3037.048869339596} 3037.048869339596
# {'tag': 'div', 'attributes': {'id': 'div-gpt-ad-topband-1628142867492-0-1', 'class': ''}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'class': 'header-container contentwrapper'}, 'score': 21.416198487095663} 21.416198487095663
# {'tag': 'div', 'attributes': {'class': 'contentwrapper'}, 'score': 721.1277173056957} 721.1277173056957
# {'tag': 'div', 'attributes': {'class': ''}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'id': 'login-popup', 'class': ''}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'class': 'Mivr2 ZwGeW '}, 'score': 14.916079783099615} 14.916079783099615
# {'tag': 'div', 'attributes': {'class': 'YZQav navigation'}, 'score': 14.916079783099615} 14.916079783099615
# {'tag': 'div', 'attributes': {'class': 'w4nQT\n              \n                undefined'}, 'score': 14.916079783099615} 14.916079783099615
# {'tag': 'div', 'attributes': {'class': 'contentwrapper rpos'}, 'score': 14.916079783099615} 14.916079783099615
# {'tag': 'div', 'attributes': {'class': 'contentwrapper clearfix    '}, 'score': 2338.7559901860554} 2338.7559901860554
# {'tag': 'div', 'attributes': {'id': 'desktop_minitv_view'}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'data-resizer-target': 'cw'}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'id': 'toi-article-container-107051526', 'class': 'clearfix rel', 'data-scrollga': 'WEB-articleshowv2#scroll#scroll_starts'}, 'score': 2338.7559901860554} 2338.7559901860554
# {'tag': 'div', 'attributes': {'class': 'NvaTO  ', 'data-translate-id': 'cw', 'data-translate-page': '1', 'data-font': 'medium', 'data-mspsectionname': 'England in India', 'data-articlemsid': '107051526'}, 'score': 2338.7559901860554} 2338.7559901860554
# {'tag': 'div', 'attributes': {'class': 'cCU6C innerbody '}, 'score': 2338.7559901860554} 2338.7559901860554
# {'tag': 'div', 'attributes': {'class': 'okf2Z '}, 'score': 1792.3666585405488} 1792.3666585405488
# {'tag': 'div', 'attributes': {'class': 'C4nji'}, 'score': 40.89949493661167} 40.89949493661167
# {'tag': 'div', 'attributes': {'class': 'undefined xciRh'}, 'score': 195.02271554554522} 195.02271554554522
# {'tag': 'div', 'attributes': {'class': 'trending_sliderContent'}, 'score': 191.34032966784156} 191.34032966784156
# {'tag': 'div', 'attributes': {'class': 'slick-slider slider variable-width slick-initialized', 'dir': 'ltr'}, 'score': 310.2842712474619} 310.2842712474619
# {'tag': 'div', 'attributes': {'class': 'slick-list'}, 'score': 550.3496987939662} 550.3496987939662
# {'tag': 'div', 'attributes': {'class': 'slick-track', 'style': 'width:0112 px135 px122 px116 px111 px116 px113 px115 px111 px108 px108 px111 px115 px113 px116 px111 px116 px122 px135 px112 px112 px135 px122 px116 px111 px116 px113 px115 px111 px108 pxpx;left:NaNpx'}, 'score': 550.3496987939662} 550.3496987939662
# {'tag': 'div', 'attributes': {'style': 'width:112 px', 'data-index': '-10', 'tabindex': '-1', 'class': 'slick-slide slick-cloned', 'aria-hidden': 'true'}, 'score': 130.832554500127} 130.832554500127
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'class': 'c5HdF', 'style': 'width:100%;display:inline-block', 'tabindex': '-1'}, 'score': 191.34032966784156} 191.34032966784156
# {'tag': 'div', 'attributes': {'style': 'width:135 px', 'data-index': '-9', 'tabindex': '-1', 'class': 'slick-slide slick-cloned', 'aria-hidden': 'true'}, 'score': 130.832554500127} 130.832554500127
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'class': 'c5HdF', 'style': 'width:100%;display:inline-block', 'tabindex': '-1'}, 'score': 191.34032966784156} 191.34032966784156
# {'tag': 'div', 'attributes': {'style': 'width:122 px', 'data-index': '-8', 'tabindex': '-1', 'class': 'slick-slide slick-cloned', 'aria-hidden': 'true'}, 'score': 130.832554500127} 130.832554500127
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'class': 'c5HdF', 'style': 'width:100%;display:inline-block', 'tabindex': '-1'}, 'score': 191.34032966784156} 191.34032966784156
# {'tag': 'div', 'attributes': {'style': 'width:116 px', 'data-index': '-7', 'tabindex': '-1', 'class': 'slick-slide slick-cloned', 'aria-hidden': 'true'}, 'score': 130.832554500127} 130.832554500127
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'class': 'c5HdF', 'style': 'width:100%;display:inline-block', 'tabindex': '-1'}, 'score': 191.34032966784156} 191.34032966784156
# {'tag': 'div', 'attributes': {'style': 'width:111 px', 'data-index': '-6', 'tabindex': '-1', 'class': 'slick-slide slick-cloned', 'aria-hidden': 'true'}, 'score': 130.832554500127} 130.832554500127
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'class': 'c5HdF', 'style': 'width:100%;display:inline-block', 'tabindex': '-1'}, 'score': 191.34032966784156} 191.34032966784156
# {'tag': 'div', 'attributes': {'style': 'width:116 px', 'data-index': '-5', 'tabindex': '-1', 'class': 'slick-slide slick-cloned', 'aria-hidden': 'true'}, 'score': 130.832554500127} 130.832554500127
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'class': 'c5HdF', 'style': 'width:100%;display:inline-block', 'tabindex': '-1'}, 'score': 191.34032966784156} 191.34032966784156
# {'tag': 'div', 'attributes': {'style': 'width:113 px', 'data-index': '-4', 'tabindex': '-1', 'class': 'slick-slide slick-cloned', 'aria-hidden': 'true'}, 'score': 130.832554500127} 130.832554500127
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'class': 'c5HdF', 'style': 'width:100%;display:inline-block', 'tabindex': '-1'}, 'score': 191.34032966784156} 191.34032966784156
# {'tag': 'div', 'attributes': {'style': 'width:115 px', 'data-index': '-3', 'tabindex': '-1', 'class': 'slick-slide slick-cloned', 'aria-hidden': 'true'}, 'score': 130.832554500127} 130.832554500127
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'class': 'c5HdF', 'style': 'width:100%;display:inline-block', 'tabindex': '-1'}, 'score': 191.34032966784156} 191.34032966784156
# {'tag': 'div', 'attributes': {'style': 'width:111 px', 'data-index': '-2', 'tabindex': '-1', 'class': 'slick-slide slick-cloned', 'aria-hidden': 'true'}, 'score': 130.832554500127} 130.832554500127
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'class': 'c5HdF', 'style': 'width:100%;display:inline-block', 'tabindex': '-1'}, 'score': 191.34032966784156} 191.34032966784156
# {'tag': 'div', 'attributes': {'style': 'width:108 px', 'data-index': '-1', 'tabindex': '-1', 'class': 'slick-slide slick-cloned', 'aria-hidden': 'true'}, 'score': 130.832554500127} 130.832554500127
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'class': 'c5HdF', 'style': 'width:100%;display:inline-block', 'tabindex': '-1'}, 'score': 191.34032966784156} 191.34032966784156
# {'tag': 'div', 'attributes': {'style': 'outline:none;width:112 px', 'data-index': '0', 'class': 'slick-slide slick-active slick-current', 'tabindex': '-1', 'aria-hidden': 'false'}, 'score': 56.54536101718726} 56.54536101718726
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'class': 'c5HdF', 'style': 'width:100%;display:inline-block', 'tabindex': '-1'}, 'score': 191.34032966784156} 191.34032966784156
# {'tag': 'div', 'attributes': {'style': 'outline:none;width:135 px', 'data-index': '1', 'class': 'slick-slide slick-active', 'tabindex': '-1', 'aria-hidden': 'false'}, 'score': 112.68438714135812} 112.68438714135812
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'class': 'c5HdF', 'style': 'width:100%;display:inline-block', 'tabindex': '-1'}, 'score': 191.34032966784156} 191.34032966784156
# {'tag': 'div', 'attributes': {'style': 'outline:none;width:122 px', 'data-index': '2', 'class': 'slick-slide slick-active', 'tabindex': '-1', 'aria-hidden': 'false'}, 'score': 112.68438714135812} 112.68438714135812
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'class': 'c5HdF', 'style': 'width:100%;display:inline-block', 'tabindex': '-1'}, 'score': 191.34032966784156} 191.34032966784156
# {'tag': 'div', 'attributes': {'style': 'outline:none;width:116 px', 'data-index': '3', 'class': 'slick-slide slick-active', 'tabindex': '-1', 'aria-hidden': 'false'}, 'score': 112.68438714135812} 112.68438714135812
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'class': 'c5HdF', 'style': 'width:100%;display:inline-block', 'tabindex': '-1'}, 'score': 191.34032966784156} 191.34032966784156
# {'tag': 'div', 'attributes': {'style': 'outline:none;width:111 px', 'data-index': '4', 'class': 'slick-slide', 'tabindex': '-1', 'aria-hidden': 'true'}, 'score': 284.1270539113887} 284.1270539113887
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'class': 'c5HdF', 'style': 'width:100%;display:inline-block', 'tabindex': '-1'}, 'score': 191.34032966784156} 191.34032966784156
# {'tag': 'div', 'attributes': {'style': 'outline:none;width:116 px', 'data-index': '5', 'class': 'slick-slide', 'tabindex': '-1', 'aria-hidden': 'true'}, 'score': 284.1270539113887} 284.1270539113887
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'class': 'c5HdF', 'style': 'width:100%;display:inline-block', 'tabindex': '-1'}, 'score': 191.34032966784156} 191.34032966784156
# {'tag': 'div', 'attributes': {'style': 'outline:none;width:113 px', 'data-index': '6', 'class': 'slick-slide', 'tabindex': '-1', 'aria-hidden': 'true'}, 'score': 284.1270539113887} 284.1270539113887
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'class': 'c5HdF', 'style': 'width:100%;display:inline-block', 'tabindex': '-1'}, 'score': 191.34032966784156} 191.34032966784156
# {'tag': 'div', 'attributes': {'style': 'outline:none;width:115 px', 'data-index': '7', 'class': 'slick-slide', 'tabindex': '-1', 'aria-hidden': 'true'}, 'score': 284.1270539113887} 284.1270539113887
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'class': 'c5HdF', 'style': 'width:100%;display:inline-block', 'tabindex': '-1'}, 'score': 191.34032966784156} 191.34032966784156
# {'tag': 'div', 'attributes': {'style': 'outline:none;width:111 px', 'data-index': '8', 'class': 'slick-slide', 'tabindex': '-1', 'aria-hidden': 'true'}, 'score': 284.1270539113887} 284.1270539113887
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'class': 'c5HdF', 'style': 'width:100%;display:inline-block', 'tabindex': '-1'}, 'score': 191.34032966784156} 191.34032966784156
# {'tag': 'div', 'attributes': {'style': 'outline:none;width:108 px', 'data-index': '9', 'class': 'slick-slide', 'tabindex': '-1', 'aria-hidden': 'true'}, 'score': 284.1270539113887} 284.1270539113887
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'class': 'c5HdF', 'style': 'width:100%;display:inline-block', 'tabindex': '-1'}, 'score': 191.34032966784156} 191.34032966784156
# {'tag': 'div', 'attributes': {'style': 'width:112 px', 'data-index': '10', 'tabindex': '-1', 'class': 'slick-slide slick-cloned', 'aria-hidden': 'true'}, 'score': 130.832554500127} 130.832554500127
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'class': 'c5HdF', 'style': 'width:100%;display:inline-block', 'tabindex': '-1'}, 'score': 191.34032966784156} 191.34032966784156
# {'tag': 'div', 'attributes': {'style': 'width:135 px', 'data-index': '11', 'tabindex': '-1', 'class': 'slick-slide slick-cloned', 'aria-hidden': 'true'}, 'score': 130.832554500127} 130.832554500127
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'class': 'c5HdF', 'style': 'width:100%;display:inline-block', 'tabindex': '-1'}, 'score': 191.34032966784156} 191.34032966784156
# {'tag': 'div', 'attributes': {'style': 'width:122 px', 'data-index': '12', 'tabindex': '-1', 'class': 'slick-slide slick-cloned', 'aria-hidden': 'true'}, 'score': 130.832554500127} 130.832554500127
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'class': 'c5HdF', 'style': 'width:100%;display:inline-block', 'tabindex': '-1'}, 'score': 191.34032966784156} 191.34032966784156
# {'tag': 'div', 'attributes': {'style': 'width:116 px', 'data-index': '13', 'tabindex': '-1', 'class': 'slick-slide slick-cloned', 'aria-hidden': 'true'}, 'score': 130.832554500127} 130.832554500127
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'class': 'c5HdF', 'style': 'width:100%;display:inline-block', 'tabindex': '-1'}, 'score': 191.34032966784156} 191.34032966784156
# {'tag': 'div', 'attributes': {'style': 'width:111 px', 'data-index': '14', 'tabindex': '-1', 'class': 'slick-slide slick-cloned', 'aria-hidden': 'true'}, 'score': 130.832554500127} 130.832554500127
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'class': 'c5HdF', 'style': 'width:100%;display:inline-block', 'tabindex': '-1'}, 'score': 191.34032966784156} 191.34032966784156
# {'tag': 'div', 'attributes': {'style': 'width:116 px', 'data-index': '15', 'tabindex': '-1', 'class': 'slick-slide slick-cloned', 'aria-hidden': 'true'}, 'score': 130.832554500127} 130.832554500127
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'class': 'c5HdF', 'style': 'width:100%;display:inline-block', 'tabindex': '-1'}, 'score': 191.34032966784156} 191.34032966784156
# {'tag': 'div', 'attributes': {'style': 'width:113 px', 'data-index': '16', 'tabindex': '-1', 'class': 'slick-slide slick-cloned', 'aria-hidden': 'true'}, 'score': 130.832554500127} 130.832554500127
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'class': 'c5HdF', 'style': 'width:100%;display:inline-block', 'tabindex': '-1'}, 'score': 191.34032966784156} 191.34032966784156
# {'tag': 'div', 'attributes': {'style': 'width:115 px', 'data-index': '17', 'tabindex': '-1', 'class': 'slick-slide slick-cloned', 'aria-hidden': 'true'}, 'score': 130.832554500127} 130.832554500127
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'class': 'c5HdF', 'style': 'width:100%;display:inline-block', 'tabindex': '-1'}, 'score': 191.34032966784156} 191.34032966784156
# {'tag': 'div', 'attributes': {'style': 'width:111 px', 'data-index': '18', 'tabindex': '-1', 'class': 'slick-slide slick-cloned', 'aria-hidden': 'true'}, 'score': 130.832554500127} 130.832554500127
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'class': 'c5HdF', 'style': 'width:100%;display:inline-block', 'tabindex': '-1'}, 'score': 191.34032966784156} 191.34032966784156
# {'tag': 'div', 'attributes': {'style': 'width:108 px', 'data-index': '19', 'tabindex': '-1', 'class': 'slick-slide slick-cloned', 'aria-hidden': 'true'}, 'score': 130.832554500127} 130.832554500127
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'class': 'c5HdF', 'style': 'width:100%;display:inline-block', 'tabindex': '-1'}, 'score': 191.34032966784156} 191.34032966784156
# {'tag': 'div', 'attributes': {'class': 'pZFl7'}, 'score': 55.42284798332008} 55.42284798332008
# {'tag': 'div', 'attributes': {'class': 't8vf3 byline_action'}, 'score': 33.53565375285274} 33.53565375285274
# {'tag': 'div', 'attributes': {'class': 'xf8Pm byline'}, 'score': 16.306623862918073} 16.306623862918073
# {'tag': 'div', 'attributes': {'class': 'eg6hg', 'data-socialshare': '107051526'}, 'score': 21.48074069840786} 21.48074069840786
# {'tag': 'div', 'attributes': {'class': 'okf2Z'}, 'score': 21.48074069840786} 21.48074069840786
# {'tag': 'div', 'attributes': {'class': 'nSsMM '}, 'score': 17.24456264653803} 17.24456264653803
# {'tag': 'div', 'attributes': {'class': 'MRCIT '}, 'score': 14.791502622129181} 14.791502622129181
# {'tag': 'div', 'attributes': {'class': 's9FOM'}, 'score': 14.599019513592784} 14.599019513592784
# {'tag': 'div', 'attributes': {'class': 'JuyWl'}, 'score': 1540.1338566591585} 1540.1338566591585
# {'tag': 'div', 'attributes': {'id': 'astro_talk_nudge'}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'class': 'vSlIC  '}, 'score': 1540.1338566591585} 1540.1338566591585
# {'tag': 'div', 'attributes': {'class': 'heightCalc'}, 'score': 1540.1338566591585} 1540.1338566591585
# {'tag': 'div', 'attributes': {'class': 'art_synopsis'}, 'score': 156.631126469709} 156.631126469709
# {'tag': 'div', 'attributes': {'data-type': 'in_view', 'class': '  '}, 'score': 1091.603672189407} 1091.603672189407
# {'tag': 'div', 'attributes': {'class': 'tCKCr  id-r-synopsis'}, 'score': 156.631126469709} 156.631126469709
# {'tag': 'div', 'attributes': {'class': 'faiOF'}, 'score': 156.631126469709} 156.631126469709
# {'tag': 'div', 'attributes': {'class': 'WEwSo'}, 'score': 156.631126469709} 156.631126469709
# {'tag': 'div', 'attributes': {'class': 'M1rHh undefined'}, 'score': 156.631126469709} 156.631126469709
# {'tag': 'div', 'attributes': {'data-articlebody': '1', 'class': 'fewcent-107051526'}, 'score': 570.589892258425} 570.589892258425
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'class': '_s30J clearfix  '}, 'score': 564.2692903071685} 564.2692903071685
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'class': 'lOvcW'}, 'score': 31.602325267042627} 31.602325267042627
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'class': 'OtxlN', 'id': 'auhtor_widget'}, 'score': 481.7490740613724} 481.7490740613724
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'class': 'f2VrG'}, 'score': 481.7490740613724} 481.7490740613724
# {'tag': 'div', 'attributes': {'class': 'kgcOp'}, 'score': 15.567764362830022} 15.567764362830022
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'class': 'GE1a7 oJgW0 '}, 'score': 471.28663395418647} 471.28663395418647
# {'tag': 'div', 'attributes': {'class': ''}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'class': ''}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'class': 'visualstoriesas_wrapper'}, 'score': 266.5599281722833} 266.5599281722833
# {'tag': 'div', 'attributes': {'data-type': 'in_view', 'class': '  '}, 'score': 1091.603672189407} 1091.603672189407
# {'tag': 'div', 'attributes': {'class': 'nXGto'}, 'score': 266.5599281722833} 266.5599281722833
# {'tag': 'div', 'attributes': {'data-type': 'in_view', 'class': '  '}, 'score': 1091.603672189407} 1091.603672189407
# {'tag': 'div', 'attributes': {'class': 'EIMcv'}, 'score': 260.7184141886165} 260.7184141886165
# {'tag': 'div', 'attributes': {'class': 'slick_UI'}, 'score': 260.7184141886165} 260.7184141886165
# {'tag': 'div', 'attributes': {'class': 'slick-slider slick-initialized', 'dir': 'ltr'}, 'score': 260.7184141886165} 260.7184141886165
# {'tag': 'div', 'attributes': {'class': 'slick-list'}, 'score': 550.3496987939662} 550.3496987939662
# {'tag': 'div', 'attributes': {'class': 'slick-track', 'style': 'width:250%;left:0%'}, 'score': 550.3496987939662} 550.3496987939662
# {'tag': 'div', 'attributes': {'data-index': '0', 'class': 'slick-slide slick-active slick-current', 'tabindex': '-1', 'aria-hidden': 'false', 'style': 'outline:none;width:10%'}, 'score': 56.54536101718726} 56.54536101718726
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'tabindex': '-1', 'style': 'width:100%;display:inline-block'}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'class': 'aTQlg'}, 'score': 255.39262183530093} 255.39262183530093
# {'tag': 'div', 'attributes': {'class': 'gycE5'}, 'score': 32.071067811865476} 32.071067811865476
# {'tag': 'div', 'attributes': {'data-index': '1', 'class': 'slick-slide slick-active', 'tabindex': '-1', 'aria-hidden': 'false', 'style': 'outline:none;width:10%'}, 'score': 112.68438714135812} 112.68438714135812
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'tabindex': '-1', 'style': 'width:100%;display:inline-block'}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'class': 'aTQlg'}, 'score': 255.39262183530093} 255.39262183530093
# {'tag': 'div', 'attributes': {'class': 'gycE5'}, 'score': 32.071067811865476} 32.071067811865476
# {'tag': 'div', 'attributes': {'data-index': '2', 'class': 'slick-slide slick-active', 'tabindex': '-1', 'aria-hidden': 'false', 'style': 'outline:none;width:10%'}, 'score': 112.68438714135812} 112.68438714135812
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'tabindex': '-1', 'style': 'width:100%;display:inline-block'}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'class': 'aTQlg'}, 'score': 255.39262183530093} 255.39262183530093
# {'tag': 'div', 'attributes': {'class': 'gycE5'}, 'score': 32.071067811865476} 32.071067811865476
# {'tag': 'div', 'attributes': {'data-index': '3', 'class': 'slick-slide slick-active', 'tabindex': '-1', 'aria-hidden': 'false', 'style': 'outline:none;width:10%'}, 'score': 112.68438714135812} 112.68438714135812
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'tabindex': '-1', 'style': 'width:100%;display:inline-block'}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'class': 'aTQlg'}, 'score': 255.39262183530093} 255.39262183530093
# {'tag': 'div', 'attributes': {'class': 'gycE5'}, 'score': 32.071067811865476} 32.071067811865476
# {'tag': 'div', 'attributes': {'data-index': '4', 'class': 'slick-slide', 'tabindex': '-1', 'aria-hidden': 'true', 'style': 'outline:none;width:10%'}, 'score': 284.1270539113887} 284.1270539113887
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'tabindex': '-1', 'style': 'width:100%;display:inline-block'}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'class': 'aTQlg'}, 'score': 255.39262183530093} 255.39262183530093
# {'tag': 'div', 'attributes': {'class': 'gycE5'}, 'score': 32.071067811865476} 32.071067811865476
# {'tag': 'div', 'attributes': {'data-index': '5', 'class': 'slick-slide', 'tabindex': '-1', 'aria-hidden': 'true', 'style': 'outline:none;width:10%'}, 'score': 284.1270539113887} 284.1270539113887
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'tabindex': '-1', 'style': 'width:100%;display:inline-block'}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'class': 'aTQlg'}, 'score': 255.39262183530093} 255.39262183530093
# {'tag': 'div', 'attributes': {'class': 'gycE5'}, 'score': 32.071067811865476} 32.071067811865476
# {'tag': 'div', 'attributes': {'data-index': '6', 'class': 'slick-slide', 'tabindex': '-1', 'aria-hidden': 'true', 'style': 'outline:none;width:10%'}, 'score': 284.1270539113887} 284.1270539113887
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'tabindex': '-1', 'style': 'width:100%;display:inline-block'}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'class': 'aTQlg'}, 'score': 255.39262183530093} 255.39262183530093
# {'tag': 'div', 'attributes': {'class': 'gycE5'}, 'score': 32.071067811865476} 32.071067811865476
# {'tag': 'div', 'attributes': {'data-index': '7', 'class': 'slick-slide', 'tabindex': '-1', 'aria-hidden': 'true', 'style': 'outline:none;width:10%'}, 'score': 284.1270539113887} 284.1270539113887
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'tabindex': '-1', 'style': 'width:100%;display:inline-block'}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'class': 'aTQlg'}, 'score': 255.39262183530093} 255.39262183530093
# {'tag': 'div', 'attributes': {'class': 'gycE5'}, 'score': 32.071067811865476} 32.071067811865476
# {'tag': 'div', 'attributes': {'data-index': '8', 'class': 'slick-slide', 'tabindex': '-1', 'aria-hidden': 'true', 'style': 'outline:none;width:10%'}, 'score': 284.1270539113887} 284.1270539113887
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'tabindex': '-1', 'style': 'width:100%;display:inline-block'}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'class': 'aTQlg'}, 'score': 255.39262183530093} 255.39262183530093
# {'tag': 'div', 'attributes': {'class': 'gycE5'}, 'score': 32.071067811865476} 32.071067811865476
# {'tag': 'div', 'attributes': {'data-index': '9', 'class': 'slick-slide', 'tabindex': '-1', 'aria-hidden': 'true', 'style': 'outline:none;width:10%'}, 'score': 284.1270539113887} 284.1270539113887
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'tabindex': '-1', 'style': 'width:100%;display:inline-block'}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'class': 'aTQlg'}, 'score': 255.39262183530093} 255.39262183530093
# {'tag': 'div', 'attributes': {'class': 'gycE5'}, 'score': 32.071067811865476} 32.071067811865476
# {'tag': 'div', 'attributes': {'data-type': 'in_view', 'class': '  '}, 'score': 1091.603672189407} 1091.603672189407
# {'tag': 'div', 'attributes': {'class': 'd4Mxk undefined articletrendinglistwrapper', 'id': ''}, 'score': 136.20828693386972} 136.20828693386972
# {'tag': 'div', 'attributes': {'class': 'whlbt articletrendinglist '}, 'score': 130.47220075561142} 130.47220075561142
# {'tag': 'div', 'attributes': {'class': 'slick-slider slider variable-width slick-initialized', 'dir': 'ltr'}, 'score': 310.2842712474619} 310.2842712474619
# {'tag': 'div', 'attributes': {'class': 'slick-list'}, 'score': 550.3496987939662} 550.3496987939662
# {'tag': 'div', 'attributes': {'class': 'slick-track', 'style': 'width:0px;left:0px'}, 'score': 550.3496987939662} 550.3496987939662
# {'tag': 'div', 'attributes': {'style': 'outline:none', 'data-index': '0', 'class': 'slick-slide slick-active slick-current', 'tabindex': '-1', 'aria-hidden': 'false'}, 'score': 56.54536101718726} 56.54536101718726
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'style': 'outline:none', 'data-index': '1', 'class': 'slick-slide', 'tabindex': '-1', 'aria-hidden': 'true'}, 'score': 284.1270539113887} 284.1270539113887
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'style': 'outline:none', 'data-index': '2', 'class': 'slick-slide', 'tabindex': '-1', 'aria-hidden': 'true'}, 'score': 284.1270539113887} 284.1270539113887
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'style': 'outline:none', 'data-index': '3', 'class': 'slick-slide', 'tabindex': '-1', 'aria-hidden': 'true'}, 'score': 284.1270539113887} 284.1270539113887
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'style': 'outline:none', 'data-index': '4', 'class': 'slick-slide', 'tabindex': '-1', 'aria-hidden': 'true'}, 'score': 284.1270539113887} 284.1270539113887
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'style': 'outline:none', 'data-index': '5', 'class': 'slick-slide', 'tabindex': '-1', 'aria-hidden': 'true'}, 'score': 284.1270539113887} 284.1270539113887
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'data-type': 'in_view', 'class': '  '}, 'score': 1091.603672189407} 1091.603672189407
# {'tag': 'div', 'attributes': {'class': 'd4Mxk undefined articletrendinglistwrapper', 'id': ''}, 'score': 136.20828693386972} 136.20828693386972
# {'tag': 'div', 'attributes': {'class': 'whlbt articletrendinglist '}, 'score': 130.47220075561142} 130.47220075561142
# {'tag': 'div', 'attributes': {'class': 'slick-slider slider variable-width slick-initialized', 'dir': 'ltr'}, 'score': 310.2842712474619} 310.2842712474619
# {'tag': 'div', 'attributes': {'class': 'slick-list'}, 'score': 550.3496987939662} 550.3496987939662
# {'tag': 'div', 'attributes': {'class': 'slick-track', 'style': 'width:0px;left:0px'}, 'score': 550.3496987939662} 550.3496987939662
# {'tag': 'div', 'attributes': {'style': 'outline:none', 'data-index': '0', 'class': 'slick-slide slick-active slick-current', 'tabindex': '-1', 'aria-hidden': 'false'}, 'score': 56.54536101718726} 56.54536101718726
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'style': 'outline:none', 'data-index': '1', 'class': 'slick-slide', 'tabindex': '-1', 'aria-hidden': 'true'}, 'score': 284.1270539113887} 284.1270539113887
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'style': 'outline:none', 'data-index': '2', 'class': 'slick-slide', 'tabindex': '-1', 'aria-hidden': 'true'}, 'score': 284.1270539113887} 284.1270539113887
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'style': 'outline:none', 'data-index': '3', 'class': 'slick-slide', 'tabindex': '-1', 'aria-hidden': 'true'}, 'score': 284.1270539113887} 284.1270539113887
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'style': 'outline:none', 'data-index': '4', 'class': 'slick-slide', 'tabindex': '-1', 'aria-hidden': 'true'}, 'score': 284.1270539113887} 284.1270539113887
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'style': 'outline:none', 'data-index': '5', 'class': 'slick-slide', 'tabindex': '-1', 'aria-hidden': 'true'}, 'score': 284.1270539113887} 284.1270539113887
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'style': 'outline:none', 'data-index': '6', 'class': 'slick-slide', 'tabindex': '-1', 'aria-hidden': 'true'}, 'score': 284.1270539113887} 284.1270539113887
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'style': 'outline:none', 'data-index': '7', 'class': 'slick-slide', 'tabindex': '-1', 'aria-hidden': 'true'}, 'score': 284.1270539113887} 284.1270539113887
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'style': 'outline:none', 'data-index': '8', 'class': 'slick-slide', 'tabindex': '-1', 'aria-hidden': 'true'}, 'score': 284.1270539113887} 284.1270539113887
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'style': 'outline:none', 'data-index': '9', 'class': 'slick-slide', 'tabindex': '-1', 'aria-hidden': 'true'}, 'score': 284.1270539113887} 284.1270539113887
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'class': 'eTaBv article_rhs Sports '}, 'score': 574.5788655293195} 574.5788655293195
# {'tag': 'div', 'attributes': {'data-mod': 'sidebar', 'data-sidebartheme': 'default', 'class': '_AmfD sidebar_ad_fix'}, 'score': 574.5788655293195} 574.5788655293195
# {'tag': 'div', 'attributes': {'data-type': 'in_view', 'class': '  '}, 'score': 1091.603672189407} 1091.603672189407
# {'tag': 'div', 'attributes': {'class': 'ISnJ7'}, 'score': 574.5788655293195} 574.5788655293195
# {'tag': 'div', 'attributes': {'class': 'kqWjC'}, 'score': 567.8681924575229} 567.8681924575229
# {'tag': 'div', 'attributes': {'class': 'ZHgwH'}, 'score': 13.29583152331272} 13.29583152331272
# {'tag': 'div', 'attributes': {'data-type': 'in_view', 'class': '  '}, 'score': 1091.603672189407} 1091.603672189407
# {'tag': 'div', 'attributes': {'id': 'affiliate_non_msp_rhs_widget'}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'data-type': 'in_view', 'class': '  '}, 'score': 1091.603672189407} 1091.603672189407
# {'tag': 'div', 'attributes': {'id': 'liner-107051526'}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'id': 'comment-sidebar-107051526'}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'data-articlepage-end': '107051526'}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'id': 'toi-article-container-107997183', 'class': 'clearfix rel'}, 'score': 2338.7559901860554} 2338.7559901860554
# {'tag': 'div', 'attributes': {'id': 'next-story-107051526', 'data-linkindex': '0', 'data-prevlinkindex': '-2'}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'id': 'toi-article-container-107046228', 'class': 'clearfix rel'}, 'score': 2338.7559901860554} 2338.7559901860554
# {'tag': 'div', 'attributes': {'id': 'next-story-107997183', 'data-linkindex': '1', 'data-prevlinkindex': '-1'}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'id': 'toi-article-container-107040105', 'class': 'clearfix rel'}, 'score': 2338.7559901860554} 2338.7559901860554
# {'tag': 'div', 'attributes': {'id': 'next-story-107046228', 'data-linkindex': '2', 'data-prevlinkindex': '0'}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'id': 'next-story-107040105', 'data-linkindex': '3', 'data-prevlinkindex': '1', 'style': 'display:none'}, 'score': 36901.5584206471} 36901.5584206471
# {'tag': 'div', 'attributes': {'data-translate-id': 'cw', 'class': 'X2plK footer_wrapper contentwrapper '}, 'score': 715.8952211790545} 715.8952211790545
# {'tag': 'div', 'attributes': {'class': 'contentwrapper'}, 'score': 721.1277173056957} 721.1277173056957
# {'tag': 'div', 'attributes': {'class': 'VRKZ3'}, 'score': 677.5812457725835} 677.5812457725835
# {'tag': 'div', 'attributes': {'class': 'D9RyY'}, 'score': 178.71231517720798} 178.71231517720798
# {'tag': 'div', 'attributes': {'class': 'undefined'}, 'score': 677.4366987102013} 677.4366987102013
# {'tag': 'div', 'attributes': {'class': 'YYaA9'}, 'score': 631.0} 631.0
# {'tag': 'div', 'attributes': {'data-type': 'in_view', 'class': '  '}, 'score': 1091.603672189407} 1091.603672189407
# {'tag': 'div', 'attributes': {'class': 'undefined'}, 'score': 677.4366987102013} 677.4366987102013
# {'tag': 'div', 'attributes': {'class': 'YYaA9'}, 'score': 631.0} 631.0
# {'tag': 'div', 'attributes': {'class': 'wvELk'}, 'score': 514.05551275464} 514.05551275464
# {'tag': 'div', 'attributes': {'class': 'undefined'}, 'score': 677.4366987102013} 677.4366987102013
# {'tag': 'div', 'attributes': {'class': 'YYaA9'}, 'score': 631.0} 631.0
# {'tag': 'div', 'attributes': {'class': 'undefined'}, 'score': 677.4366987102013} 677.4366987102013
# {'tag': 'div', 'attributes': {'class': 'YYaA9'}, 'score': 631.0} 631.0
# {'tag': 'div', 'attributes': {'class': 'undefined'}, 'score': 677.4366987102013} 677.4366987102013
# {'tag': 'div', 'attributes': {'class': 'YYaA9'}, 'score': 631.0} 631.0
# {'tag': 'div', 'attributes': {'class': 'undefined'}, 'score': 677.4366987102013} 677.4366987102013
# {'tag': 'div', 'attributes': {'class': 'YYaA9'}, 'score': 631.0} 631.0
# {'tag': 'div', 'attributes': {'class': 'undefined'}, 'score': 677.4366987102013} 677.4366987102013
# {'tag': 'div', 'attributes': {'class': 'YYaA9'}, 'score': 631.0} 631.0
# {'tag': 'div', 'attributes': {'class': 'undefined'}, 'score': 677.4366987102013} 677.4366987102013
# {'tag': 'div', 'attributes': {'class': 'YYaA9'}, 'score': 631.0} 631.0
# {'tag': 'div', 'attributes': {'class': 'nVZnl'}, 'score': 47.53565375285274} 47.53565375285274
# {'tag': 'p', 'attributes': {'class': 'efT4r'}, 'score': 31.602325267042627} 31.602325267042627
# {'tag': 'p', 'attributes': {'class': 'ObA_k'}, 'score': 229.34523505985752} 229.34523505985752
# {'tag': 'p', 'attributes': {'class': 'ObA_k'}, 'score': 229.34523505985752} 229.34523505985752
# {'tag': 'p', 'attributes': {'class': 'ObA_k'}, 'score': 229.34523505985752} 229.34523505985752
# {'tag': 'p', 'attributes': {'class': 'ObA_k'}, 'score': 229.34523505985752} 229.34523505985752
# {'tag': 'p', 'attributes': {'class': 'ObA_k'}, 'score': 229.34523505985752} 229.34523505985752
# {'tag': 'p', 'attributes': {'class': 'ObA_k'}, 'score': 229.34523505985752} 229.34523505985752
# {'tag': 'p', 'attributes': {'class': 'ObA_k'}, 'score': 229.34523505985752} 229.34523505985752
# {'tag': 'p', 'attributes': {'class': 'ObA_k'}, 'score': 229.34523505985752} 229.34523505985752
# {'tag': 'p', 'attributes': {'class': 'ObA_k'}, 'score': 229.34523505985752} 229.34523505985752
# {'tag': 'p', 'attributes': {'class': 'ObA_k'}, 'score': 229.34523505985752} 229.34523505985752

# %%
print(len(get_text(top_node)))
# Out:
# 534

# %%
from lxmlparser1 import HTMLParser

# %%
from bs4 import BeautifulSoup
from dateutil.parser import parse as date_parser


class CustomExtractor:
    def __init__(self):
        self.stopwords = stop_words
        # self.parser = HTMLParser

    def calculate_gravity_score(self, tag):
        # Your custom logic to calculate the gravity score
        # This example uses the length of text content as a score
        text_content = tag.get_text(strip=True)
        return len(text_content)

    def previousSiblings(self,node):
      try:
        return [n for n in node.itersiblings(preceding=True)]
      except:
        return []
    def walk_siblings(self, node):
        # Iterate over siblings
        return self.previousSiblings(node)

    def is_highlink_density(self, node):

        # For simplicity, this example checks if the node contains more than 5 links
        links = node.find_all('a')
        return len(links) > 25



    def is_boostable(self, node):
        para = "p"
        steps_away = 0
        minimum_stopword_count = 2
        max_stepsaway_from_node = 3

        nodes = self.walk_siblings(node)
        # print(len(nodes))
        for current_node in nodes:
            current_node_tag = current_node.name
            if current_node_tag == para:
                if steps_away >= max_stepsaway_from_node:
                    return False
                paragraph_text = current_node.get_text(strip=True)
                word_stats = self.get_stopword_count(paragraph_text)
                # print(word_stats)
                if word_stats > minimum_stopword_count:
                    return True
                steps_away += 1
        return False

    def get_stopword_count(self, text):
        text = re.sub(r'[^\w\s]', '', text)
        words = [word.lower() for word in text.split()]

        sm = 0
        for word in words:
          if(word in self.stopwords):
            sm+=1
        return sm


    def count_paragraph_tags_on_same_level_with_depth(self,element, depth=0):
        paragraph_tags = element.find_all('p', recursive=False)
        if paragraph_tags:
            return len(paragraph_tags), depth
        for child in element.children:
            if node is not None:
                num_paragraphs, child_depth = count_paragraph_tags_on_same_level_with_depth(child, depth=depth+1)
                if num_paragraphs:
                    return num_paragraphs, child_depth
            else:
                return 0, 0
        return 0, 0


    def count_br_tags_on_same_level_with_depth(self,element, depth=0):
        paragraph_tags = element.find_all('br', recursive=False)
        if paragraph_tags:
            return len(paragraph_tags), depth
        for child in element.children:
            if node is not None:
                num_paragraphs, child_depth = self.count_br_tags_on_same_level_with_depth(child, depth=depth+1)
                if num_paragraphs:
                    return num_paragraphs, child_depth
            else:
                return 0, 0
        return 0, 0



    def calculate_best_node(self, soup):
        top_node = None
        top_node_score = 0
        nodes_to_check = self.nodes_to_check(soup)
        # print(nodes_to_check)
        starting_boost = 1.0
        cnt = 0
        i = 0
        parent_nodes = []
        nodes_with_text = []


        for node in nodes_to_check:
            text_node = node.get_text()
            word_stats = self.get_stopword_count(text_node)
#             print(node.get_text(strip=True))
            # print(word_stats)
            high_link_density = self.is_highlink_density(node)
            if word_stats >= 2 and not high_link_density:
                nodes_with_text.append(node)

        nodes_number = len(nodes_with_text)
        negative_scoring = 0
        bottom_negativescore_nodes = nodes_number * 0.25

#         print(nodes_with_text)
        for node in nodes_with_text:

#             print(type(node))
            boost_score = 0
            depth = 0

            boost_score3 = 0
            depth3 = 0

            try:
                boost_score, depth = count_paragraph_tags_on_same_level_with_depth(node)
    #                print(node['class'], " ", boost_score)
            except:
                boost_score = 0

            try:
              boost_score3, depth3 = self.count_br_tags_on_same_level_with_depth(node)
            except:
              depth3 += 0

            text_node = node.get_text(strip=True)
            word_stats = self.get_stopword_count(text_node)/2
            temp = 0

            try:
                temp = len(node.content)
            except:
                pass

            boost_score2 = 0
            if(self.is_boostable(node)):
              print("Hello ")
              boost_score2 = 5

            try:
              if 'article' in node['class'][0].split():
                word_stats += 10
            except:
                word_stats += 0
            try:
              if 'content' in node['class'][0].split():
                word_stats += 10
            except:
                word_stats += 0

            boost_score = boost_score*(0.95**(depth+1))
            upscore = word_stats + boost_score + boost_score2 + boost_score3*(0.95**(depth3+1))


            # class_pattern = re.compile(r'\b(?:article|content)\b', re.IGNORECASE)


#             print(upscore," ",word_stats," ",boost_score," ",word_stats+boost_score)



            parent_node = node.parent

            self.update_score(node,upscore)


            if(node['score'] > top_node_score):
              top_node = node
              top_node_score = node['score']

            # print(node.name," ",word_stats," ",boost_score," ",boost_score3," ",node['score']," ",upscore)

            parent_nodes.append(node)
            # print(node.name," ",len(parent_nodes))
            # try:
            #   print(node['class'])
            # except:
            #   boost_score += 0

            x = node
            if(node.name == 'p'):
                for i in range(5):
                    x = x.parent
                    self.update_score(x,upscore*((0.8)**i))

            if parent_node not in parent_nodes:
                parent_nodes.append(parent_node)

            parent_parent_node = parent_node.parent
            if parent_parent_node is not None:
                self.update_node_count(parent_parent_node, 1)

                if parent_parent_node not in parent_nodes:
                    parent_nodes.append(parent_parent_node)
            cnt += 1
            i += 1


        # print(len(parent_nodes))
        for e in parent_nodes:
            # print(node.name," ",node['score'])
            score = self.get_score(e)

            if score > top_node_score:
#                 print(node.name," ",node['score'])
                top_node = e
                top_node_score = score

            if top_node is None:
                top_node = e

        return top_node

    def nodes_to_check(self, soup):
        nodes_to_check = []
        for tag in ['div','p', 'pre', 'td']:
            items = soup.find_all(tag)
            nodes_to_check += items
#         print(nodes_to_check)
        return nodes_to_check


    def update_score(self, node, score):
        if 'score' not in node:
            node['score'] = len(node.get_text(strip=True))**(0.5)
        node['score'] += score

    def update_node_count(self, node, count):
        if 'count' not in node:
            node['count'] = 0

        node['count'] += count

    def get_score(self, node):
        return node.get('score', 0)

    def get_authors(self, doc):
        def contains_digits(d):
            for char in d:
                if char.isdigit():
                    return True
            return False

        def unique_list(lst):
            count = {}
            list = []
            for item in lst:
                if item.lower() in count:
                    continue
                count[item.lower()] = 1
                list.append(item.title())
            return list

        def parse(str):

            str = ''.join(char for char in str if char != '<' and char != '>')

            str = str.replace('By:', '').replace('From:', '').strip()

            names = [s.strip() for s in re.split(r"[^\w\'\-\.]", str) if s]


            authors = []
            current = []
            delimiters = ['and', ',', '']

            for name in names:
                if name in delimiters:
                    if len(current) > 0:
                        authors.append(' '.join(current))
                        current = []
                elif not contains_digits(name):
                    current.append(name)

            valid_name = (len(current) >= 2)
            if valid_name:
                authors.append(' '.join(current))

            return authors
        patterns=[re.compile(r'(?:author.*?name|name.*?author)', re.IGNORECASE)]
        attributes = ['name', 'rel', 'itemprop', 'class', 'id']
        variables = ['author', 'byline', 'dc.creator', 'byl','group-info']
        matches = []
        authors = []

        for attr in attributes:
            for val in variables+patterns:
                found = doc.find_all(attrs={attr: val})
                matches.extend(found)


        for match in matches:
            content = ''
            if match.tag == 'meta':
                content_value = match.get('content')
                if len(content_value) > 0:
                    content = content_value[0]
            else:
                content = match.get_text() or ''
            if len(content) > 0:
                authors.extend(parse(content))

        return unique_list(authors)

    def publishing_date(self, url, doc):
        def parse_date(str):
            if str:
                try:
                    return date_parser(str)
                except (ValueError, OverflowError, AttributeError, TypeError):
                    return None


        STRICT_DATE_REGEX = re.compile(r'\/(\d{4})\/(\d{2})\/(\d{2})\/')
        date_pattern = re.compile(r'(\d{2} [a-zA-Z]{3} \d{4}) (\d{2}:\d{2}[APMapm]{2})')
        date_match = STRICT_DATE_REGEX.search(url)
        if date_match:
            str = date_match.group(0)
            datetime = parse_date(str)
            if datetime:
                return datetime


        date_tags = [
            {'attribute': ('property', 'rnews:datePublished'), 'content': 'content'},
            {'attribute': ('property', 'article:published_time'), 'content': 'content'},
            {'attribute': ('name', 'OriginalPublicationDate'), 'content': 'content'},
            {'attribute': ('itemprop', 'datePublished'), 'content': 'datetime'},
            {'attribute': ('property', 'og:published_time'), 'content': 'content'},
            {'attribute': ('name', 'article_date_original'), 'content': 'content'},
            {'attribute': ('name', 'publication_date'), 'content': 'content'},
            {'attribute': ('name', 'sailthru.date'), 'content': 'content'},
            {'attribute': ('name', 'PublishDate'), 'content': 'content'},
            {'attribute': ('pubdate', 'pubdate'), 'content': 'datetime'},
            {'attribute': ('name', 'publish_date'), 'content': 'content'},
        ]



        patterns = re.compile(r'(?:article.*publish|publish.*article|\bdate\b|\btime\b)')

        for tags in date_tags:
            meta_tags = doc.find_all(attrs={tags['attribute'][0]: tags['attribute'][1]})
            if meta_tags:
                str = meta_tags[0].get(tags['content'])
                datetime = parse_date(str)
                if datetime:
                    return datetime

        additional_date_tag = doc.find('div', class_=lambda c: c and patterns.search(c))
        if additional_date_tag:
            str = additional_date_tag.get_text(strip=True)
            match = date_pattern.search(str)
            if match:
                date_str, time_str = match.groups()

                # Combine date and time, then parse using dateutil.parser
                datetime_str = f"{date_str} {time_str}"
                datetime_obj = date_parser(datetime_str)
            return datetime_obj



        # If none of the strategies work, return None
        return None
    def split_title(self,title, splitter, hint=None):
        """Split the title to best part possible"""
        large_text_length = 0
        large_text_index = 0
        title_pieces = title.split(splitter)
        if hint and hint!='':
            filter_regex = re.compile(r'[^a-zA-Z0-9\ ]')
            hint = filter_regex.sub('', hint).lower()

        # find the largest title piece
        for i, title_piece in enumerate(title_pieces):
            current = title_piece.strip()
            #Immediately break if any part matches
            if hint and hint in filter_regex.sub('', current).lower():
                large_text_index = i
                break
            if len(current) > large_text_length:
                large_text_length = len(current)
                large_text_index = i

    #     Even if no part matches with hint(h1) if prints simply the longest part as the parts
    #     are usually of independent meaning
        title = title_pieces[large_text_index]
        return title
    def get_title(self,soup):
        """Explicit rules:
        1. title == h1, no need to split
        2. h1 similar to og:title, use h1
        3. title contains h1, title contains og:title, len(h1) > len(og:title), use h1
        4. title starts with og:title, use og:title
        5. use title, after splitting
        """
        title = ''
        title_element = soup.title

        # no title found
        if title_element is None or len(title_element) == 0:
            print("Error")
            return title

        # title elem found
        title_text = title_element.text
        used_delimeter = False

    #     title from h1
            # - extract the longest text from all h1 elements
        # - too short texts (fewer than 2 words) are discarded
        # - clean double spaces
    #     h1_element = soup.find_all('h1')[0]
    #     title_text_h1 = h1_element.text
        title_text_h1=''
        title_element_h1_list = soup.find_all('h1')
        title_text_h1_list = [tag.get_text(strip=True) for tag in title_element_h1_list]
        if title_text_h1_list:
            title_text_h1_list.sort(key=len, reverse=True)
            #longest title
            title_text_h1 = title_text_h1_list[0]
            # clean double spaces
            title_text_h1 = ' '.join([x for x in title_text_h1.split() if x])
        #title from meta tag(not user-visible)
        meta_tag_content = soup.find({'meta': {'property': 'og:title'}})
        if not meta_tag_content:
            meta_tag_content = soup.find({'meta': {'name': 'og:title'}})
        title_text_meta = meta_tag_content.get('content', '')  # Empty string if no meta tag found
        # Further filtering of unwanted characters
        # Alphanumeric characters, punctuation and alphanumeric
        filter_regex = re.compile(r'[^a-zA-Z0-9\ ]')
        filter_title_text = filter_regex.sub('', title_text).lower()
        filter_title_text_h1 = filter_regex.sub('', title_text_h1).lower()
        filter_title_text_meta = filter_regex.sub('', title_text_meta).lower()

        # Case1: If both matches don't do anything
        if title_text_h1 == title_text:
            used_delimeter = True
        # Case2: h1 and meta tag matches(either of h1 or meta)
        elif filter_title_text_h1 and filter_title_text_h1 == filter_title_text_meta:
            title_text = title_text_h1
            used_delimeter = True
        # Case3: If both h1 and meta are a substring of title_text(use h1)
        elif filter_title_text_h1 and filter_title_text_h1 in filter_title_text and filter_title_text_meta in filter_title_text  and len(title_text_h1) > len(title_text_meta):
            title_text = title_text_h1
            used_delimeter = True
        # Case4: If title_text startswith meta text(replace with meta)
        elif filter_title_text_meta and filter_title_text_meta != filter_title_text and filter_title_text.startswith(filter_title_text_meta):
            title_text = title_text_meta
            used_delimeter = True

        # If none of the above condition is matched, means a delimiter must be present between them
        # Now individually parts separated by delimiter has to be checked and now we check with h1 tag only(no meta tag)-Observation based
        if not used_delimeter and '|' in title_text:
            title_text = self.split_title(title_text, '|', title_text_h1)
            used_delimeter = True

        # self.split title with -
        if not used_delimeter and '-' in title_text:
            title_text = self.split_title(title_text, '-', title_text_h1)
            used_delimeter = True

        # self.split title with _
        if not used_delimeter and '_' in title_text:
            title_text = self.split_title(title_text, '_', title_text_h1)
            used_delimeter = True

        # self.split title with /
        if not used_delimeter and '/' in title_text:
            title_text = self.split_title(title_text, '/', title_text_h1)
            used_delimeter = True

        # self.split title with »
        if not used_delimeter and ' » ' in title_text:
            title_text = self.split_title(title_text, ' » ', title_text_h1)
            used_delimeter = True
        return title_text

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from urllib.parse import urlencode

url="https://www.gadgetsnow.com/gn-advertorial/enter-the-new-era-of-mobile-technology-as-samsung-is-all-set-to-introduce-the-revolutionary-galaxy-ai/articleshow/106867089.cms?upcache=2&_gl=1*1ncy8wg*_ga*MzI4MzUwNDA5LjE2OTI1NTY4MTQ.*_ga_FCN624MN68*MTcwNTkxOTU1Ny4xMS4xLjE3MDU5MTk4MTIuNjAuMC4w"
proxies = {
"http": "http://scraperapi:8355bf750256f87924cb321115d06996@proxy-server.scraperapi.com:8001"
}
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}

response = requests.get(url,headers=headers,proxies=proxies,verify=False)
API_KEY = "8355bf750256f87924cb321115d06996"
params = {'api_key': API_KEY, 'url': url}
response = requests.get('http://api.scraperapi.com/', params=urlencode(params))
response.raise_for_status()

soup = BeautifulSoup(response.text, 'html.parser')

# print(soup)
# Create an instance of CustomExtractor
extractor = CustomExtractor()


# authors_list=extractor.get_authors(soup);
# print("authors  are")

# if authors_list:

#     for author in authors_list:
#         print(author)

# else:
#     print("No authors found.")
# date=extractor.publishing_date(url,soup)

# print("date of publication:",date)

# title_list=extractor.get_title(soup);
# print("title  is/are")

# print(extractor.get_title(soup))


# Calculate best node based on custom gravity scores
best_node = extractor.calculate_best_node(soup)

print("\n\n")
# Now, you can access the best node and its gravity score
if best_node:
    print(f"Best Node: {best_node['class']}, Gravity Score: {best_node.get('score', 0)}")
    print(best_node.get_text(strip=True))
else:
    print("No best node found.")
# Out:
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py:1020: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.gadgetsnow.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Best Node: ['ULEYK'], Gravity Score: 82.96190165613635
# As a tech brand, Samsung is known for its futuristic vision, which has permanently changed how people connect and interact with technology. Be it the jaw-dropping world's first TV phone or the iconic MP3 phone, Samsung has always pushed the boundaries in terms of innovation, and this year, too, it's bringing never-seen-before features that will stun the world.This January, the smartphone industry will witness an exciting entry as Samsung is all set to unveil its futuristic devices at its most-awaited Samsung Unpacked event, which is taking place on January 17th. Viewers can catch the live stream at 11.30 pm on the Samsung website. The excitement to experience something new and different has set expectations higher.Galaxy AI is comingWith Artificial Intelligence taking over the world, it is imperative that it should also come in handy and rest in our pockets. Smartphone technology is yet to see and experience the magic of AI. Samsung is bringing just that with itsGalaxy AI, which will offer a brand-new AI experience fueled by on-device AI developed at Samsung and cloud-based AI facilitated through open collaborations with industry leaders who share the brand’s vision. It will enhance people's everyday mobile experience and ensure top-notch security and privacy features.Talking about the path-breaking innovations, Wonjoon Choi, EVP and Head of R&D, Mobile eXperience Business, said, "Mobile technology has an incredible power to enable connection, productivity, creativity and more for people around the world, but until now, we haven't seen mobile AI ignite that in truly meaningful ways. Galaxy AI is our most comprehensive intelligence offering to date, and it will change how we think about our phones forever."Make way for the ‘Galaxy Experience Spaces’This time, the Galaxy AI is bringing an A-level game with Galaxy Experience Spaces. These spaces will introduce the new Galaxy AI and its unique possibilities and features to Samsung fans. Once the visitors enter the spaces and whatever they experience, the same will be available to them through the Galaxy's newest devices. Samsung is also setting up this one-of-a-kind experience zone at the India event, and it will be available to users through exclusive invites.Samsung teases new AI-powered capabilities in anticipation of#SamsungUnpacked, partnering with@Marvelstudiosfor an epic takeover of the sphere in Las Vegas.pic.twitter.com/FXBhsIlCOD— Samsung India (@SamsungIndia)January 10, 2024Mark the calendarAll eyes would be set on Samsung Unpacked 2024 which will happen on January 17th, 2024. Viewers can catch the streaming at 11.30 pm on Samsung.com. The world is anticipating the entry of the Galaxy AI, which will bring a new era of mobile phones. It's time to witness the same!People who want to experience the future of smartphones canpre-reservethe devices now and avail themselves of the benefits of Rs 5000.Disclaimer: This article has been produced on behalf of Samsung by the Times Internet's Spotlight team.end of article

# %%
print(best_node)
# Out:
# <div class="ULEYK" data-articlebody="1" score="82.96190165613635"><div class="ciclF"><figure><img alt="Enter the new era of mobile technology, as Samsung is all set to introduce the revolutionary Galaxy AI" src="https://static.toiimg.com/thumb/resizemode-4,msid-106871524,imgsize-22592,width-720/106871524.jpg"/></figure></div><div class="hc6dh"></div><div data-lhsawid="106867089"></div><div class="mb16"></div><div></div><div></div><span>As a tech brand, Samsung is known for its futuristic vision, which has permanently changed how people connect and interact with technology. Be it the jaw-dropping world's first TV phone or the iconic MP3 phone, Samsung has always pushed the boundaries in terms of innovation, and this year, too, it's bringing never-seen-before features that will stun the world.</span><br/><br/><span>This January, the smartphone industry will witness an exciting entry as Samsung is all set to unveil its futuristic devices at its most-awaited Samsung Unpacked event, which is taking place on January 17<sup>th</sup>. Viewers can catch the live stream at 11.30 pm on the Samsung website. The excitement to experience something new and different has set expectations higher.</span><br/><br/><span><b>Galaxy AI is coming </b></span><br/><br/><span> With Artificial Intelligence taking over the world, it is imperative that it should also come in handy and rest in our pockets. Smartphone technology is yet to see and experience the magic of AI. Samsung is bringing just that with its </span><a class="eventSelector" clink="y" href="https://www.samsung.com/in/unpacked/" rel="noopener nofollow noreferrer" target="_blank">Galaxy AI</a><span>, which will offer a brand-new AI experience fueled by on-device AI developed at Samsung and cloud-based AI facilitated through open collaborations with industry leaders who share the brand’s vision. It will enhance people's everyday mobile experience and ensure top-notch security and privacy features.</span><br/><br/><span> </span><div class="bmSWg"><iframe frameborder="0" scrolling="no" src="https://www.youtube.com/embed/lKoG2_zdoSA?autoplay=0&amp;fs=0&amp;iv_load_policy=3&amp;showinfo=0&amp;rel=0&amp;cc_load_policy=0&amp;start=0&amp;end=0&amp;origin=https://youtubeembedcode.com" title="videowidget" type="text/html"></iframe></div><br/><br/><span>Talking about the path-breaking innovations, Wonjoon Choi, EVP and Head of R&amp;D, Mobile eXperience Business, said, "Mobile technology has an incredible power to enable connection, productivity, creativity and more for people around the world, but until now, we haven't seen mobile AI ignite that in truly meaningful ways. Galaxy AI is our most comprehensive intelligence offering to date, and it will change how we think about our phones forever."</span><br/><br/><span><b>Make way for the ‘Galaxy Experience Spaces’</b></span><br/><br/><span>This time, the Galaxy AI is bringing an A-level game with Galaxy Experience Spaces. These spaces will introduce the new Galaxy AI and its unique possibilities and features to Samsung fans. Once the visitors enter the spaces and whatever they experience, the same will be available to them through the Galaxy's newest devices. Samsung is also setting up this one-of-a-kind experience zone at the India event, and it will be available to users through exclusive invites.</span><br/><br/><span> </span><br/><span> </span><span><blockquote class="twitter-tweet"><p dir="ltr" lang="en">Samsung teases new AI-powered capabilities in anticipation of <a href="https://twitter.com/hashtag/SamsungUnpacked?src=hash&amp;ref_src=twsrc%5Etfw">#SamsungUnpacked</a>, partnering with <a href="https://twitter.com/MarvelStudios?ref_src=twsrc%5Etfw">@Marvelstudios</a> for an epic takeover of the sphere in Las Vegas. <a href="https://t.co/FXBhsIlCOD">pic.twitter.com/FXBhsIlCOD</a></p>— Samsung India (@SamsungIndia) <a href="https://twitter.com/SamsungIndia/status/1745108947185344773?ref_src=twsrc%5Etfw">January 10, 2024</a></blockquote> <script as ...

# %%
def is_valid_datetime(datetime_string):
    # Define a regex pattern for the specified datetime format
    pattern = r'^[A-Z][a-z]{2}\s\d{1,2},\s\d{4}\s\d{1,2}:\d{2}\s(?:AM|PM)$'

    # Check if the string matches the pattern
    if re.match(pattern, datetime_string):
        return True
    else:
        return False

# %%
def process_text(text, words_to_delete_pattern=None):
    # Split the text into a list of strings using full stops and question marks as delimiters
    text_list = [part.strip() for part in re.split(r'(?<!\d)\.|\?(?!\d)', text)]

#     # Check if text is a valid datetime
    if is_valid_datetime(text):
        return ''
    print(text_list)
    print("\n\n")
    # If words_to_delete_pattern is provided, use it to remove undesired words
    if words_to_delete_pattern:
        text_list = [part for part in text_list if not any(words_to_delete_pattern.findall(part))]

    # Join the remaining strings in the list to form the text in order
    processed_text = ' '.join(text_list)

    return processed_text

# %%
# Define undesired word patterns for each category
advertisement_pattern = r'\bads?\b|Advertisement|advertisements'
technical_issues_pattern = r'sorry|try again|audio is unavailable|AI-generated|PopularContent is loading|Content is loading'
subscription_pattern = r'subscribe|purchase'
feedback_pattern = r'feedback'
# Add more patterns for other categories if needed

# Combine all patterns into a single regular expression
undesired_words_pattern = re.compile(
    f'{advertisement_pattern}|{technical_issues_pattern}|{subscription_pattern}|{feedback_pattern}',
    re.IGNORECASE
)

# undesired_words_pattern = None
print(best_node.get_text(strip=True))
print("\n\n")
print(process_text(best_node.get_text(strip=True),undesired_words_pattern))
# Out:
# As a tech brand, Samsung is known for its futuristic vision, which has permanently changed how people connect and interact with technology. Be it the jaw-dropping world's first TV phone or the iconic MP3 phone, Samsung has always pushed the boundaries in terms of innovation, and this year, too, it's bringing never-seen-before features that will stun the world.This January, the smartphone industry will witness an exciting entry as Samsung is all set to unveil its futuristic devices at its most-awaited Samsung Unpacked event, which is taking place on January 17th. Viewers can catch the live stream at 11.30 pm on the Samsung website. The excitement to experience something new and different has set expectations higher.Galaxy AI is comingWith Artificial Intelligence taking over the world, it is imperative that it should also come in handy and rest in our pockets. Smartphone technology is yet to see and experience the magic of AI. Samsung is bringing just that with itsGalaxy AI, which will offer a brand-new AI experience fueled by on-device AI developed at Samsung and cloud-based AI facilitated through open collaborations with industry leaders who share the brand’s vision. It will enhance people's everyday mobile experience and ensure top-notch security and privacy features.Talking about the path-breaking innovations, Wonjoon Choi, EVP and Head of R&D, Mobile eXperience Business, said, "Mobile technology has an incredible power to enable connection, productivity, creativity and more for people around the world, but until now, we haven't seen mobile AI ignite that in truly meaningful ways. Galaxy AI is our most comprehensive intelligence offering to date, and it will change how we think about our phones forever."Make way for the ‘Galaxy Experience Spaces’This time, the Galaxy AI is bringing an A-level game with Galaxy Experience Spaces. These spaces will introduce the new Galaxy AI and its unique possibilities and features to Samsung fans. Once the visitors enter the spaces and whatever they experience, the same will be available to them through the Galaxy's newest devices. Samsung is also setting up this one-of-a-kind experience zone at the India event, and it will be available to users through exclusive invites.Samsung teases new AI-powered capabilities in anticipation of#SamsungUnpacked, partnering with@Marvelstudiosfor an epic takeover of the sphere in Las Vegas.pic.twitter.com/FXBhsIlCOD— Samsung India (@SamsungIndia)January 10, 2024Mark the calendarAll eyes would be set on Samsung Unpacked 2024 which will happen on January 17th, 2024. Viewers can catch the streaming at 11.30 pm on Samsung.com. The world is anticipating the entry of the Galaxy AI, which will bring a new era of mobile phones. It's time to witness the same!People who want to experience the future of smartphones canpre-reservethe devices now and avail themselves of the benefits of Rs 5000.Disclaimer: This article has been produced on behalf of Samsung by the Times Internet's Spotlight team.end of article
#
#
#
# ['As a tech brand, Samsung is known for its futuristic vision, which has permanently changed how people connect and interact with technology', "Be it the jaw-dropping world's first TV phone or the iconic MP3 phone, Samsung has always pushed the boundaries in terms of innovation, and this year, too, it's bringing never-seen-before features that will stun the world", 'This January, the smartphone industry will witness an exciting entry as Samsung is all set to unveil its futuristic devices at its most-awaited Samsung Unpacked event, which is taking place on January 17th', 'Viewers can catch the live stream at 11.30 pm on the Samsung website', 'The excitement to experience something new and different has set expectations higher', 'Galaxy AI is comingWith Artificial Intelligence taking over the world, it is imperative that it should also come in handy and rest in our pockets', 'Smartphone technology is yet to see and experience the magic of AI', 'Samsung is bringing just that with itsGalaxy AI, which will offer a brand-new AI experience fueled by on-device AI developed at Samsung and cloud-based AI facilitated through open collaborations with industry leaders who share the brand’s vision', "It will enhance people's everyday mobile experience and ensure top-notch security and privacy features", 'Talking about the path-breaking innovations, Wonjoon Choi, EVP and Head of R&D, Mobile eXperience Business, said, "Mobile technology has an incredible power to enable connection, productivity, creativity and more for people around the world, but until now, we haven\'t seen mobile AI ignite that in truly meaningful ways', 'Galaxy AI is our most comprehensive intelligence offering to date, and it will change how we think about our phones forever', '"Make way for the ‘Galaxy Experience Spaces’This time, the Galaxy AI is bringing an A-level game with Galaxy Experience Spaces', 'These spaces will introduce the new Galaxy AI and its unique possibilities and features to Samsung fans', "Once the visitors enter the spaces and whatever they experience, the same will be available to them through the Galaxy's newest devices", 'Samsung is also setting up this one-of-a-kind experience zone at the India event, and it will be available to users through exclusive invites', 'Samsung teases new AI-powered capabilities in anticipation of#SamsungUnpacked, partnering with@Marvelstudiosfor an epic takeover of the sphere in Las Vegas', 'pic', 'twitter', 'com/FXBhsIlCOD— Samsung India (@SamsungIndia)January 10, 2024Mark the calendarAll eyes would be set on Samsung Unpacked 2024 which will happen on January 17th, 2024. Viewers can catch the streaming at 11.30 pm on Samsung', 'com', 'The world is anticipating the entry of the Galaxy AI, which will bring a new era of mobile phones', "It's time to witness the same!People who want to experience the future of smartphones canpre-reservethe devices now and avail themselves of the benefits of Rs 5000.Disclaimer: This article has been produced on behalf of Samsung by the Times Internet's Spotlight team", 'end of article']
#
#
#
# As a tech brand, Samsung is known for its futuristic vision, which has permanently changed how people connect and interact with technology Be it the jaw-dropping world's first TV phone or the iconic MP3 phone, Samsung has always pushed the boundaries in terms of innovation, and this year, too, it's bringing never-seen-before features that will stun the world This January, the smartphone industry will witness an exciting entry as Samsung is all set to unveil its futuristic devices at its most-awaited Samsung Unpacked event, which is taking place on January 17th Viewers can catch the live stream at 11.30 pm on the Samsung website The excitement to experience something new and different has set expectations higher Galaxy AI is comingWith Artificial Intelligence taking over the world, it is imperative that it should also come in handy and rest in our pockets Smartphone technology is yet to see and experience the magic of AI Samsung is bringing just that with itsGalaxy AI, which will offer a brand-new AI experience fueled by on-device AI developed at Samsung and cloud-based AI facilitated through open collaborations with industry leaders who share the brand’s vision It will enhance people's everyday mobile experience and ensure top-notch security and privacy features Talking about the path-breaking innovations, Wonjoon Choi, EVP and Head of R&D, Mobile eXperience Business, said, "Mobile technology has an incredible power to enable connection, productivity, creativity and more for people around the world, but until now, we haven't seen mobile AI ignite that in truly meaningful ways Galaxy AI is our most comprehensive intelligence offering to date, and it will change how we think about our phones forever "Make way for the ‘Galaxy Experience Spaces’This time, the Galaxy AI is bringing an A-level game with Galaxy Experience Spaces These spaces will introduce the new Galaxy AI and its unique possibilities and features to Samsung fans Once the visitors enter the spaces and whatever they experience, the same will be available to them through the Galaxy's newest devices Samsung is also setting up this one-of-a-kind experience zone at the India event, and it will be available to users through exclusive invites Samsung teases new AI-powered capabilities in anticipation of#SamsungUnpacked, partnering with@Marvelstudiosfor an epic takeover of the sphere in Las Vegas pic twitter com/FXBhsIlCOD— Samsung India (@SamsungIndia)January 10, 2024Mark the calendarAll eyes would be set on Samsung Unpacked 2024 which will happen on January 17th, 2024. Viewers can catch the streaming at 11.30 pm on Samsung com The world is anticipating the entry of the Galaxy AI, which will bring a new era of mobile phones It's time to witness the same!People who want to experience the future of smartphones canpre-reservethe devices now and avail themselves of the benefits of Rs 5000.Disclaimer: This article has been produced on behalf of Samsung by the Times Internet's Spotlight team end of article

# %%
paragraphs = best_node.find_all('p')  # Find all paragraph elements
paragraph_texts = [paragraph.get_text(strip=True) for paragraph in paragraphs]  # Extract text from each paragraph
z = ' '.join(paragraph_texts)  # Concatenate text of all paragraphs
if(len(z)> 0):
    print(z)
# Out:
# Samsung teases new AI-powered capabilities in anticipation of#SamsungUnpacked, partnering with@Marvelstudiosfor an epic takeover of the sphere in Las Vegas.pic.twitter.com/FXBhsIlCOD

# %%
content = []
tag_types = ['p','div','span']

for node in best_node.find_all(tag_types):
  # print(node.get_text())
  # print("Yes")
  try:
    if(len(node.find_all()) == 0):
      if(len(node.get_text(strip=True)) >= 10 ):
        content.append(node.get_text(strip=True))
  except:
    continue

if(len(content) > 0):
  for x in content:
    print(x)
# Out:
# As a tech brand, Samsung is known for its futuristic vision, which has permanently changed how people connect and interact with technology. Be it the jaw-dropping world's first TV phone or the iconic MP3 phone, Samsung has always pushed the boundaries in terms of innovation, and this year, too, it's bringing never-seen-before features that will stun the world.
# With Artificial Intelligence taking over the world, it is imperative that it should also come in handy and rest in our pockets. Smartphone technology is yet to see and experience the magic of AI. Samsung is bringing just that with its
# , which will offer a brand-new AI experience fueled by on-device AI developed at Samsung and cloud-based AI facilitated through open collaborations with industry leaders who share the brand’s vision. It will enhance people's everyday mobile experience and ensure top-notch security and privacy features.
# Talking about the path-breaking innovations, Wonjoon Choi, EVP and Head of R&D, Mobile eXperience Business, said, "Mobile technology has an incredible power to enable connection, productivity, creativity and more for people around the world, but until now, we haven't seen mobile AI ignite that in truly meaningful ways. Galaxy AI is our most comprehensive intelligence offering to date, and it will change how we think about our phones forever."
# This time, the Galaxy AI is bringing an A-level game with Galaxy Experience Spaces. These spaces will introduce the new Galaxy AI and its unique possibilities and features to Samsung fans. Once the visitors enter the spaces and whatever they experience, the same will be available to them through the Galaxy's newest devices. Samsung is also setting up this one-of-a-kind experience zone at the India event, and it will be available to users through exclusive invites.
# All eyes would be set on Samsung Unpacked 2024 which will happen on January 17th, 2024. Viewers can catch the streaming at 11.30 pm on Samsung.com. The world is anticipating the entry of the Galaxy AI, which will bring a new era of mobile phones. It's time to witness the same!
# People who want to experience the future of smartphones can
# the devices now and avail themselves of the benefits of Rs 5000.
# end of article

# %%
import re

content = []

#No article tag taken
tag_types = ['p', 'div', 'span']
# Define undesired word patterns for each category
advertisement_pattern = r'\bads?\b|Advertisement|advertisements'
technical_issues_pattern = r'sorry|try again|audio is unavailable|AI-generated|Content is loading'
subscription_pattern = r'subscribe|purchase'
feedback_pattern = r'feedback'
footer_pattern = r'read\s*more'

# Add more patterns for other categories if needed

# Combine all patterns into a single regular expression
undesired_words_pattern = re.compile(
    f'{advertisement_pattern}|{technical_issues_pattern}|{subscription_pattern}|{feedback_pattern}|{footer_pattern}',
    re.IGNORECASE
)



for node in best_node.find_all(tag_types[0]) + best_node.find_all(tag_types[2]):
    try:
       if len(node.find_all()) == 0 or any(child.name in ['a', 'em', 'span'] for child in node.children):


            text = node.get_text(strip=True)
            text = process_text(text,undesired_words_pattern)
            if len(text) >= 10:
                content.append(text)
    except:
        continue


fin = []
if len(content) > 0:
    for x in content:
        if(x not in fin):
          fin.append(x)
    for x in fin:
      print(x)

else:
  for node in best_node.find_all(tag_types[1]):
    try:
        if len(node.find_all()) == 0 :
            text = node.get_text(strip=True)
            text = process_text(text)
            if len(text) >= 10:
                content.append(text)
    except:
        continue

  fin = []
  if len(content) > 0:
    for x in content:
        if(x not in fin):
          fin.append(x)
    for x in fin:
      print(x)
  else:
    print("Hello")
# Out:
# ['Samsung teases new AI-powered capabilities in anticipation of#SamsungUnpacked, partnering with@Marvelstudiosfor an epic takeover of the sphere in Las Vegas', 'pic', 'twitter', 'com/FXBhsIlCOD']
#
#
#
# ['As a tech brand, Samsung is known for its futuristic vision, which has permanently changed how people connect and interact with technology', "Be it the jaw-dropping world's first TV phone or the iconic MP3 phone, Samsung has always pushed the boundaries in terms of innovation, and this year, too, it's bringing never-seen-before features that will stun the world", '']
#
#
#
# ['With Artificial Intelligence taking over the world, it is imperative that it should also come in handy and rest in our pockets', 'Smartphone technology is yet to see and experience the magic of AI', 'Samsung is bringing just that with its']
#
#
#
# [', which will offer a brand-new AI experience fueled by on-device AI developed at Samsung and cloud-based AI facilitated through open collaborations with industry leaders who share the brand’s vision', "It will enhance people's everyday mobile experience and ensure top-notch security and privacy features", '']
#
#
#
# ['']
#
#
#
# ['Talking about the path-breaking innovations, Wonjoon Choi, EVP and Head of R&D, Mobile eXperience Business, said, "Mobile technology has an incredible power to enable connection, productivity, creativity and more for people around the world, but until now, we haven\'t seen mobile AI ignite that in truly meaningful ways', 'Galaxy AI is our most comprehensive intelligence offering to date, and it will change how we think about our phones forever', '"']
#
#
#
# ['This time, the Galaxy AI is bringing an A-level game with Galaxy Experience Spaces', 'These spaces will introduce the new Galaxy AI and its unique possibilities and features to Samsung fans', "Once the visitors enter the spaces and whatever they experience, the same will be available to them through the Galaxy's newest devices", 'Samsung is also setting up this one-of-a-kind experience zone at the India event, and it will be available to users through exclusive invites', '']
#
#
#
# ['']
#
#
#
# ['']
#
#
#
# ['All eyes would be set on Samsung Unpacked 2024 which will happen on January 17th, 2024. Viewers can catch the streaming at 11.30 pm on Samsung', 'com', 'The world is anticipating the entry of the Galaxy AI, which will bring a new era of mobile phones', "It's time to witness the same!"]
#
#
#
# ['People who want to experience the future of smartphones can']
#
#
#
# ['the devices now and avail themselves of the benefits of Rs 5000.']
#
#
#
# ['end of article']
#
#
#
# Samsung teases new AI-powered capabilities in anticipation of#SamsungUnpacked, partnering with@Marvelstudiosfor an epic takeover of the sphere in Las Vegas pic twitter com/FXBhsIlCOD
# As a tech brand, Samsung is known for its futuristic vision, which has permanently changed how people connect and interact with technology Be it the jaw-dropping world's first TV phone or the iconic MP3 phone, Samsung has always pushed the boundaries in terms of innovation, and this year, too, it's bringing never-seen-before features that will stun the world
# With Artificial Intelligence taking over the world, it is imperative that it should also come in handy and rest in our pockets Smartphone technology is yet to see and experience the magic of AI Samsung is bringing just that with its
# , which will offer a brand-new AI experience fueled by on-device AI developed at Samsung and cloud-based AI facilitated through open collaborations with industry leaders who share the brand’s vision It will enhance people's everyday mobile experience and ensure top-notch security and privacy features
# Talking about the path-breaking innovations, Wonjoon Choi, EVP and Head of R&D, Mobile eXperience Business, said, "Mobile technology has an incredible power to enable connection, productivity, creativity and more for people around the world, but until now, we haven't seen mobile AI ignite that in truly meaningful ways Galaxy AI is our most comprehensive intelligence offering to date, and it will change how we think about our phones forever "
# This time, the Galaxy AI is bringing an A-level game with Galaxy Experience Spaces These spaces will introduce the new Galaxy AI and its unique possibilities and features to Samsung fans Once the visitors enter the spaces and whatever they experience, the same will be available to them through the Galaxy's newest devices Samsung is also setting up this one-of-a-kind experience zone at the India event, and it will be available to users through exclusive invites
# All eyes would be set on Samsung Unpacked 2024 which will happen on January 17th, 2024. Viewers can catch the streaming at 11.30 pm on Samsung com The world is anticipating the entry of the Galaxy AI, which will bring a new era of mobile phones It's time to witness the same!
# People who want to experience the future of smartphones can
# the devices now and avail themselves of the benefits of Rs 5000.
# end of article
