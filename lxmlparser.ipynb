# %%
from lxml import html
import requests



class HTMLParser:
    def __init__(self, html_content):
        self.tree = html.fromstring(html_content)

    def get_text_by_tag(self, tag_name=None, attribute_name=None, attribute_value=None):
        if tag_name and attribute_name and attribute_value:
            xpath_query = f'//{tag_name}[@{attribute_name}="{attribute_value}"]'
        elif not tag_name and attribute_name and attribute_value:
        
            xpath_query = f'//*[@{attribute_name}="{attribute_value}"]'
        else:
            xpath_query = f'//{tag_name}'
    
        elements = self.tree.xpath(xpath_query)
    
        result_list = []
        for element in elements:
            result_list.append(element.text_content().strip())
    
        return result_list


    
    def parent(self, tag_name=None, attribute_name=None, attribute_value=None):
        result_list = []
    
        if tag_name and attribute_name and attribute_value:
            xpath_query = f'//{tag_name}[@{attribute_name}="{attribute_value}"]'
        elif not tag_name and attribute_name and attribute_value:
            xpath_query = f'//*[@{attribute_name}="{attribute_value}"]'
        else:
            xpath_query = f'//{tag_name}'
    
        elements = self.tree.xpath(xpath_query)
    
        for element in elements:
            parent = element.getparent()
            if parent is not None:
                result_dict = {'tag': parent.tag, 'attributes': {}}
                
                
                for key, value in parent.items():
                    result_dict['attributes'][key] = value
                
                result_list.append(result_dict)
    
        return result_list


    def children(self, tag_name=None, attribute_name=None, attribute_value=None):
        result_list = []
        if tag_name and attribute_name and attribute_value:
            xpath_query = f'//{tag_name}[@{attribute_name}="{attribute_value}"]'
        elif not tag_name and attribute_name and attribute_value:
            xpath_query = f'//*[@{attribute_name}="{attribute_value}"]'
        else:
            xpath_query = f'//{tag_name}'
        
        elements = self.tree.xpath(xpath_query)
        for element in elements:
            parent = element.getparent()
            if parent is not None:
                result_dict = {'tag': parent.tag, 'attributes': {}}
                    
                    
                for key, value in parent.items():
                    result_dict['attributes'][key] = value
                    
                result_list.append(result_dict)
        
        return result_list
    
    def find_all_next(self, tag_name=None, attribute_name=None, attribute_value=None):
        result_list = []

        if tag_name and attribute_name and attribute_value:
            xpath_query = f'//{tag_name}[@{attribute_name}="{attribute_value}"]/following-sibling::*'
        elif not tag_name and attribute_name and attribute_value:
            xpath_query = f'//*[@{attribute_name}="{attribute_value}"]/following-sibling::*'
        elif tag_name:
            xpath_query = f'//{tag_name}/following-sibling::*'
        else:
        # Handle the case where neither tag_name nor attribute_name and attribute_value are provided
            return result_list

        elements = self.tree.xpath(xpath_query)

        for element in elements:
            result_dict = {'tag': element.tag,  'attributes': {}}

            # Append attributes and their values to the result_dict
            for key, value in element.items():
                result_dict['attributes'][key] = value

            result_list.append(result_dict)

        return result_list


    def find_all_tags(self, tag_name):
        result_list = []

        elements = self.tree.xpath(f'//{tag_name}')

        for element in elements:
            result_dict = {'tag': element.tag, 'attributes': {}}

            # Append attributes and their values to the result_dict
            for key, value in element.items():
                result_dict['attributes'][key] = value

            result_list.append(result_dict)

        return result_list


    def find_all_by_attribute(self, attribute_name=None, attribute_value=None):
        result_list = []

        if attribute_name and attribute_value:
            xpath_query = f'//*[@{attribute_name}="{attribute_value}"]'
        elif attribute_name:
            xpath_query = f'//*[@{attribute_name}]'
        elif attribute_value:
            xpath_query = f'//*[@*="{attribute_value}"]'
        else:
            # Handle the case where neither attribute_name nor attribute_value is provided
            return result_list
    
        elements = self.tree.xpath(xpath_query)
    
        for element in elements:
            result_dict = {'tag': element.tag, 'attributes': {}}
    
            # Append attributes and their values to the result_dict
            for key, value in element.items():
                result_dict['attributes'][key] = value
    
            result_list.append(result_dict)
    
        return result_list

# %%
url="https://edition.cnn.com/middleeast/live-news/israel-hamas-war-gaza-news-02-04-24/index.html"
response = requests.get(url)
response.raise_for_status()  # Raise an HTTPError for bad responses

html_content= response.text
parser=HTMLParser(html_content)


print(parser.get_text_by_tag(attribute_name="data-type",attribute_value="byline-area"))
print(parser.parent(attribute_name="data-type",attribute_value="byline-area"))
print(parser.children("div","class","sc-dnqmqq sc-hSdWYo fKJYAI"))
print(parser.find_all_next("div"))
print()
print()
# Out:
# ['By Andrew Raine and Heather Chen, CNN']
# [{'tag': 'div', 'attributes': {'class': 'sc-dnqmqq sc-hSdWYo fKJYAI'}}]
# [{'tag': 'div', 'attributes': {'class': 'headline'}}]
# [{'tag': 'div', 'attributes': {'class': 'sc-dBAPYN fJPuOh'}}, {'tag': 'div', 'attributes': {'mode': 'dark', 'class': 'sc-dKEPtC eMwtza'}}, {'tag': 'div', 'attributes': {'class': 'sc-eIHaNI iYNlZu'}}, {'tag': 'div', 'attributes': {'class': 'sc-ugnQR cacWpd'}}, {'tag': 'div', 'attributes': {'class': 'sc-gzVnrw sc-gtfDJT sc-fOICqy fAKPnY'}}, {'tag': 'div', 'attributes': {'class': 'sc-bdVaJa sc-ipXKqB gaNIBv'}}, {'tag': 'div', 'attributes': {'class': 'sc-bdVaJa fAvHax'}}, {'tag': 'div', 'attributes': {'class': 'sc-gzVnrw sc-bEjcJn iIifdK'}}, {'tag': 'div', 'attributes': {'class': 'sc-gzVnrw sc-gtfDJT dQXmwZ'}}, {'tag': 'div', 'attributes': {'style': 'false:unset', 'class': 'sc-htoDjs sc-etwtAo sc-iGPElx esqSIM'}}, {'tag': 'div', 'attributes': {'class': 'sc-bdVaJa kRdOVD'}}, {'tag': 'div', 'attributes': {'class': 'sc-bdVaJa bGHAiF'}}, {'tag': 'div', 'attributes': {'class': 'sc-bdVaJa fJTuuG'}}, {'tag': 'div', 'attributes': {'class': 'sc-bdVaJa sc-eInJlc eCVPRf'}}, {'tag': 'hr', 'attributes': {'mode': 'dark', 'class': 'sc-hgHYgh iHydNh'}}, {'tag': 'div', 'attributes': {'id': 'edition-picker-mobile', 'data-open': 'false', 'tabindex': '-1', 'data-zjs': 'click', 'data-zjs-campaign': 'header-edition-picker', 'class': 'sc-bdVaJa sc-iGrrsa iCWZSz'}}, {'tag': 'div', 'attributes': {'class': 'sc-bdVaJa sc-dEoRIm loCIvl'}}, {'tag': 'hr', 'attributes': {'mode': 'dark', 'class': 'sc-hgHYgh iHydNh'}}, {'tag': 'div', 'attributes': {'class': 'sc-gzVnrw sc-gtfDJT jZpWgW'}}, {'tag': 'hr', 'attributes': {'mode': 'dark', 'class': 'sc-hgHYgh hOADLT'}}, {'tag': 'div', 'attributes': {'class': 'sc-bdVaJa ksnaEV'}}, {'tag': 'div', 'attributes': {'class': 'sc-gzVnrw sc-hzDEsm fPLfFQ'}}, {'tag': 'div', 'attributes': {'class': 'sc-isBZXS dTsiKp'}}, {'tag': 'div', 'attributes': {}}, {'tag': 'div', 'attributes': {'class': 'sc-dvpmds ddhRhw'}}, {'tag': 'div', 'attributes': {'class': 'sc-bdVaJa hOFtnA'}}, {'tag': 'div', 'attributes': {'mode': 'light', 'class': 'sc-bdVaJa pageTopstyles__PageTopWrapper-sc-1a1dxnt-0 hUkLTQ'}}, {'tag': 'div', 'attributes': {'class': 'content pageTopstyles__ContentContainer-sc-1a1dxnt-4 beDFsn'}}, {'tag': 'span', 'attributes': {}}, {'tag': 'div', 'attributes': {'class': 'headline'}}, {'tag': 'div', 'attributes': {}}, {'tag': 'div', 'attributes': {'class': '_7eda40eb _34e5cb16 _4564d500'}}, {'tag': 'p', 'attributes': {'class': 'sc-gZMcBi render-stellar-contentstyles__Paragraph-sc-9v7nwy-2 dCwndB'}}, {'tag': 'div', 'attributes': {'data-open': 'false', 'class': 'sc-bdVaJa sc-iyvyFf hoANdN'}}, {'tag': 'div', 'attributes': {'class': 'sc-eLExRp iakwgk'}}, {'tag': 'div', 'attributes': {'id': 'posts-and-button', 'style': 'position:relative'}}, {'tag': 'p', 'attributes': {'class': 'sc-gZMcBi render-stellar-contentstyles__Paragraph-sc-9v7nwy-2 dCwndB'}}, {'tag': 'p', 'attributes': {'class': 'sc-gZMcBi render-stellar-contentstyles__Paragraph-sc-9v7nwy-2 dCwndB'}}, {'tag': 'div', 'attributes': {'class': 'sc-bdVaJa sc-RefOD bkVmOx'}}, {'tag': 'p', 'attributes': {'class': 'sc-gZMcBi render-stellar-contentstyles__Paragraph-sc-9v7nwy-2 dCwndB'}}, {'tag': 'p', 'attributes': {'class': 'sc-gZMcBi render-stellar-contentstyles__Paragraph-sc-9v7nwy-2 dCwndB'}}, {'tag': 'p', 'attributes': {'class': 'sc-gZMcBi render-stellar-contentstyles__Paragraph-sc-9v7nwy-2 dCwndB'}}, {'tag': 'div', 'attributes': {'data-open': 'false', 'class': 'sc-bdVaJa sc-iyvyFf hoANdN'}}, {'tag': 'div', 'attributes': {'data-open': 'false', 'class': 'sc-bdVaJa sc-iyvyFf hoANdN'}}, {'tag': 'p', 'attributes': {'class': 'sc-gZMcBi render-stellar-contentstyles__Paragraph-sc-9v7nwy-2 dCwndB'}}, {'tag': 'p', 'attributes': {'class': 'sc-gZMcBi render-stellar-contentstyles__Paragraph-sc-9v7nwy-2 dCwndB'}}, {'tag': 'div', 'attributes': {'data-open': 'false', 'class': 'sc-bdVaJa sc-iyvyFf hoANdN'}}, {'tag': 'p', 'attributes': {'class': 'sc-gZMcBi render-stellar-contentstyles__Paragraph-sc-9v7nwy-2 dCwndB'}}, {'tag': 'p', 'attributes': {'class': 'sc-gZMcBi render-stellar-contentstyles__Paragraph ...
#
#
# [{'tag': 'div', 'attributes': {'id': 'mount'}}, {'tag': 'div', 'attributes': {}}, {'tag': 'div', 'attributes': {'class': 'sc-dBAPYN fJPuOh'}}, {'tag': 'div', 'attributes': {'mode': 'dark', 'class': 'sc-dKEPtC eMwtza'}}, {'tag': 'div', 'attributes': {}}, {'tag': 'div', 'attributes': {'id': 'ad_bnr_atf_01', 'data-ad-branding': ''}}, {'tag': 'div', 'attributes': {'class': 'sc-eIHaNI iYNlZu'}}, {'tag': 'div', 'attributes': {'class': 'sc-ugnQR cacWpd'}}, {'tag': 'div', 'attributes': {'class': 'sc-dnqmqq sc-clNaTc rkUIQ'}}, {'tag': 'div', 'attributes': {'class': 'sc-htoDjs sc-etwtAo kysRUW'}}, {'tag': 'div', 'attributes': {'class': 'sc-bZQynM sc-jXQZqI eddiF'}}, {'tag': 'div', 'attributes': {'size': '40', 'class': 'sc-gzVnrw sc-krDsej fvlcZO'}}, {'tag': 'div', 'attributes': {'class': 'sc-gzVnrw sc-gtfDJT sc-fOICqy fAKPnY'}}, {'tag': 'div', 'attributes': {'data-test': 'moreMenu', 'tabindex': '-1', 'class': 'sc-bdVaJa sc-VJcYb iqTNLd'}}, {'tag': 'div', 'attributes': {'tabindex': '0', 'style': 'outline:0', 'class': 'sc-gzVnrw sc-kLIISr gwFZCX'}}, {'tag': 'div', 'attributes': {'class': 'sc-bdVaJa sc-ipXKqB gaNIBv'}}, {'tag': 'div', 'attributes': {'class': 'sc-bdVaJa fAvHax'}}, {'tag': 'div', 'attributes': {'class': 'sc-gzVnrw sc-bEjcJn iIifdK'}}, {'tag': 'div', 'attributes': {'class': 'sc-gzVnrw sc-gtfDJT dQXmwZ'}}, {'tag': 'div', 'attributes': {'style': 'false:unset', 'class': 'sc-htoDjs sc-etwtAo sc-iGPElx esqSIM'}}, {'tag': 'div', 'attributes': {'class': 'sc-bZQynM sc-kasBVs eJvIol'}}, {'tag': 'div', 'attributes': {'class': 'sc-bdVaJa sc-eInJlc dxXowM'}}, {'tag': 'div', 'attributes': {'class': 'sc-bdVaJa kRdOVD'}}, {'tag': 'div', 'attributes': {'class': 'sc-dnqmqq kMlcms'}}, {'tag': 'div', 'attributes': {'class': 'sc-bdVaJa bGHAiF'}}, {'tag': 'div', 'attributes': {'class': 'sc-bdVaJa fJTuuG'}}, {'tag': 'div', 'attributes': {'class': 'sc-bdVaJa sc-eInJlc eCVPRf'}}, {'tag': 'div', 'attributes': {'class': 'sc-gzVnrw sc-likbZx iffUTd'}}, {'tag': 'div', 'attributes': {'class': 'sc-gzVnrw sc-drMfKT bkdlwu'}}, {'tag': 'div', 'attributes': {'id': 'edition-picker-mobile', 'data-open': 'false', 'tabindex': '-1', 'data-zjs': 'click', 'data-zjs-campaign': 'header-edition-picker', 'class': 'sc-bdVaJa sc-iGrrsa iCWZSz'}}, {'tag': 'div', 'attributes': {'role': 'button', 'id': 'edition-picker-toggle-mobile', 'tabindex': '0', 'style': 'outline:0', 'class': 'sc-gzVnrw sc-kaNhvL hIBnmm'}}, {'tag': 'div', 'attributes': {'class': 'sc-bdVaJa sc-dEoRIm loCIvl'}}, {'tag': 'div', 'attributes': {'class': 'sc-gzVnrw sc-gtfDJT jZpWgW'}}, {'tag': 'div', 'attributes': {'class': 'sc-gzVnrw sc-jeCdPy jNrnWG'}}, {'tag': 'div', 'attributes': {'class': 'sc-gzVnrw sc-hIVACf bVkItX'}}, {'tag': 'div', 'attributes': {'class': 'sc-bdVaJa ksnaEV'}}, {'tag': 'div', 'attributes': {'class': 'sc-gzVnrw sc-hzDEsm fPLfFQ'}}, {'tag': 'div', 'attributes': {'data-test': 'social-follow-bar', 'class': 'sc-gzVnrw sc-kxynE fHFYMm'}}, {'tag': 'div', 'attributes': {'class': 'sc-isBZXS dTsiKp'}}, {'tag': 'div', 'attributes': {}}, {'tag': 'div', 'attributes': {'class': 'sc-dvpmds ddhRhw'}}, {'tag': 'div', 'attributes': {'class': 'sc-bdVaJa QYVrQ'}}, {'tag': 'div', 'attributes': {'class': 'ls-event-tray event-traystyles__EventTrayWrapper-sy7kkw-0 eLpYeO', 'mode': 'light'}}, {'tag': 'div', 'attributes': {'id': 'livestory-ribbon', 'class': 'event-traystyles__EventsContainer-sy7kkw-1 eHJdtV'}}, {'tag': 'div', 'attributes': {'class': 'sc-bHwgHz fnmjZV'}}, {'tag': 'div', 'attributes': {'class': 'ribbon-container sc-bMvGRv eMWRFy', 'mode': 'light'}}, {'tag': 'div', 'attributes': {'class': 'sc-gzVnrw sc-CtfFt dWUjAA'}}, {'tag': 'div', 'attributes': {'class': 'sc-bdVaJa hOFtnA'}}, {'tag': 'div', 'attributes': {'disabled': '', 'class': 'sc-bdVaJa event-traystyles__EventBox-sy7kkw-3 trMRc'}}, {'tag': 'div', 'attributes': {'class': 'sc-bdVaJa hOFtnA'}}, {'tag': 'div', 'attributes': {'class': 'sc-bdVaJa event-traystyles__EventBox-sy7kkw-3 cVrkTo'}}, {'tag': 'div', 'attributes': {'mode': 'light', 'class' ...

# %%
print(parser.find_all_by_attribute("class"))
# Out:
# [{'tag': 'div', 'attributes': {'class': 'sc-dBAPYN fJPuOh'}}, {'tag': 'div', 'attributes': {'mode': 'dark', 'class': 'sc-dKEPtC eMwtza'}}, {'tag': 'div', 'attributes': {'class': 'sc-eIHaNI iYNlZu'}}, {'tag': 'div', 'attributes': {'class': 'sc-ugnQR cacWpd'}}, {'tag': 'header', 'attributes': {'mode': 'dark', 'id': 'header-nav-container', 'data-zjs-campaign': 'header-wrapper', 'class': 'sc-bxivhb sc-fQejPQ dpgTwu'}}, {'tag': 'div', 'attributes': {'class': 'sc-dnqmqq sc-clNaTc rkUIQ'}}, {'tag': 'div', 'attributes': {'class': 'sc-htoDjs sc-etwtAo kysRUW'}}, {'tag': 'div', 'attributes': {'class': 'sc-bZQynM sc-jXQZqI eddiF'}}, {'tag': 'button', 'attributes': {'id': 'menuButton', 'tabindex': '-1', 'data-test': 'menuButton', 'data-zjs': 'click', 'data-zjs-campaign': 'header-expanded-nav-btn', 'class': 'sc-gmeYpB sc-iSDuPN bzpxnC'}}, {'tag': 'svg', 'attributes': {'class': 'menu-icon', 'style': 'outline:0', 'width': '24', 'height': '24', 'viewbox': '0 0 64 64', 'fill': 'currentColor', 'tabindex': '0', 'focusable': 'true', 'xmlns': 'https://www.w3.org/2000/svg', 'aria-labelledby': 'menuIconTitle', 'role': 'img'}}, {'tag': 'div', 'attributes': {'size': '40', 'class': 'sc-gzVnrw sc-krDsej fvlcZO'}}, {'tag': 'a', 'attributes': {'href': '/', 'aria-label': 'CNN', 'data-analytics': 'header_top-nav', 'color': '#0C0C0C', 'mode': 'light', 'class': 'sc-kGXeez sc-kpOJdX dxuEhj'}}, {'tag': 'svg', 'attributes': {'class': 'cnn-badge-icon', 'style': 'outline:0', 'width': '40', 'height': '40', 'viewbox': '0 0 240 240', 'fill': '#CC0000', 'xmlns': 'https://www.w3.org/2000/svg', 'aria-hidden': 'true'}}, {'tag': 'a', 'attributes': {'href': '/world', 'aria-label': 'World', 'mode': 'dark', 'data-analytics': 'header_top-nav', 'data-test': 'section-link', 'color': '#0C0C0C', 'class': 'sc-kGXeez sc-kpOJdX sc-dTdPqK drHduu'}}, {'tag': 'div', 'attributes': {'class': 'sc-gzVnrw sc-gtfDJT sc-fOICqy fAKPnY'}}, {'tag': 'nav', 'attributes': {'mode': 'dark', 'data-role': 'nav-links', 'class': 'sc-eMigcr cZMHPG'}}, {'tag': 'ul', 'attributes': {'mode': 'dark', 'type': 'collapsed', 'class': 'sc-fzsDOv gNNNEm'}}, {'tag': 'li', 'attributes': {'mode': 'dark', 'type': 'collapsed', 'data-section': 'africa', 'data-selected': 'false', 'class': 'sc-gPWkxV bsGySX'}}, {'tag': 'a', 'attributes': {'mode': 'dark', 'type': 'collapsed', 'name': 'africa', 'href': '/world/africa', 'data-analytics': 'header_top-nav', 'title': 'visit the Africa section', 'class': 'sc-itybZL sc-jVODtj eyCFaW'}}, {'tag': 'li', 'attributes': {'mode': 'dark', 'type': 'collapsed', 'data-section': 'americas', 'data-selected': 'false', 'class': 'sc-gPWkxV bsGySX'}}, {'tag': 'a', 'attributes': {'mode': 'dark', 'type': 'collapsed', 'name': 'americas', 'href': '/world/americas', 'data-analytics': 'header_top-nav', 'title': 'visit the Americas section', 'class': 'sc-itybZL sc-jVODtj eyCFaW'}}, {'tag': 'li', 'attributes': {'mode': 'dark', 'type': 'collapsed', 'data-section': 'asia', 'data-selected': 'false', 'class': 'sc-gPWkxV bsGySX'}}, {'tag': 'a', 'attributes': {'mode': 'dark', 'type': 'collapsed', 'name': 'asia', 'href': '/world/asia', 'data-analytics': 'header_top-nav', 'title': 'visit the Asia section', 'class': 'sc-itybZL sc-jVODtj eyCFaW'}}, {'tag': 'li', 'attributes': {'mode': 'dark', 'type': 'collapsed', 'data-section': 'australia', 'data-selected': 'false', 'class': 'sc-gPWkxV bsGySX'}}, {'tag': 'a', 'attributes': {'mode': 'dark', 'type': 'collapsed', 'name': 'australia', 'href': '/world/australia', 'data-analytics': 'header_top-nav', 'title': 'visit the Australia section', 'class': 'sc-itybZL sc-jVODtj eyCFaW'}}, {'tag': 'div', 'attributes': {'data-test': 'moreMenu', 'tabindex': '-1', 'class': 'sc-bdVaJa sc-VJcYb iqTNLd'}}, {'tag': 'div', 'attributes': {'tabindex': '0', 'style': 'outline:0', 'class': 'sc-gzVnrw sc-kLIISr gwFZCX'}}, {'tag': 'li', 'attributes': {'type': 'collapsed', 'class': 'sc-gPWkxV sc-qrIAp jHUoVK'}}, {'tag': 'div', 'attributes': {'class': 'sc-bdVaJa sc-ipXKqB gaNIBv'}}, {'tag': 'ul', ' ...

# %%
print(parser.find_all_by_attribute("class","sc-dnqmqq sc-hSdWYo fKJYAI"))
# Out:
# [{'tag': 'div', 'attributes': {'class': 'sc-dnqmqq sc-hSdWYo fKJYAI'}}]

# %%
print(parser.find_all_by_attribute(attribute_value="sc-dnqmqq sc-hSdWYo fKJYAI"))
# Out:
# [{'tag': 'div', 'attributes': {'class': 'sc-dnqmqq sc-hSdWYo fKJYAI'}}]
